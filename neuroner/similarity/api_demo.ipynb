# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from similarity import similarity
from similarity_intra import load_ontologies

# Computes the intra and inter semantic similarity between two neurons
# in: n1@str, n2@str: the two neurons to measure similarity
# out: (score:float, [(matching_properties, explanation@str)])
#similarity('PV Layer 1 cortex acetylcholine neuron', 'Layer 1a striatum gaba fast-spiking neuron')
similarity('Periventricular zone layer 5a neuron', 'Hypothalamic medial zone layer 5-6 neuron')
# Out:
# (0.6987179487179488,
#  [(['HBP_LAYER:0000005'], 'shares layers'),
#   (['ABA_REGION:1097'], 'sibling regions'),
#   [],
#   [],
#   [],
#   [],
#   [],
#   []])

# %%
import pandas as pd


# download neuroelectro summary spreadsheet from URL and import into pandas data frame
neuroelectro_dataset_url = "http://dev.neuroelectro.org/static/src/article_ephys_metadata_curated.csv"
table = pd.read_csv(neuroelectro_dataset_url, sep='\t', index_col = 0, header=0)

# %%
big_onto = load_ontologies()

# %%
name_spaces = [('NCBI_GENE', 'gene'), ('HBP_LAYER', 'layer'), ('HBP_MORPHOLOGY', 'shape'), ('REGION', 'region'),
              ('HBP_EPHYS', 'ephys'), ('MOUSE_LINE', 'line'),]
proj_name = 'projection'

proj_list = ['CStr', 'CSp', 'CThal', 'CCo', 'CTrig', 'CTect']

def annots_to_dict(annot_list):
    temp_dict = {}
    for annotation in annot_list:
        for s in name_spaces:
            if s[0] in annotation:
                term = _normalize([annotation], shorten = True)
                if term in proj_list:
                    temp_dict[proj_name] = term
                    continue
                if s[1] not in temp_dict:
                    temp_dict[s[1]] = term
                else:
                    temp_dict[s[1]] = '%s %s' %  (temp_dict[s[1]],  term)
    return temp_dict

# %%
strain_list = ['GIN', 'G42', 'GAD65-GFP', 'Thy1-YFP']
def add_animal_strain_to_neuron(input_neuron_name, strain):
    output_neuron_name = input_neuron_name

    if strain in strain_list:
        #output_neuron_name += ' from %s mouse line' % strain
        output_neuron_name += ' %s' % strain
    return output_neuron_name
def check_strain(neuron_name):
    for s in strain_list:
        if s in neuron_name:
            return 'MOUSE_LINE:%s' % s
    return None
check_strain('Hypothalamic medial zone dopaminergic neuron from Thy1-YFP mouse line')
# Out:
# 'MOUSE_LINE:Thy1-YFP'

# %%
from sherlok import Sherlok
s = Sherlok('neuroner')

from similarity import _cleanup, _normalize

neuron_name = 'Neocortex corticostriatal NPY somatostatin-expressing with depolarizing fast spiking AHP Layer 5a pyramidal cell GIN'
r = s.annotate(neuron_name)
#annot_list = format_annots(neuron_name, r.annotations)
al = _cleanup(r.annotations, neuron_name)
if check_strain(neuron_name):
    al.append(check_strain(neuron_name))
print _normalize(al, shorten = True)

#print annot_list
print al
# Out:
# Isocortex CStr Npy Sst with depolarizing F S AHP L5a Pyr GIN GIN
# [u'ABA_REGION:315', 'HBP_PROJECTION:7322', u'NCBI_GENE:109648', u'NCBI_GENE:20604', 'Missing:with depolarizing', u'HBP_EPHYS:0000080', u'HBP_EPHYS_TRIGGER:0000003', 'Missing:AHP', u'HBP_LAYER:0000050', u'HBP_MORPHOLOGY:0000001', 'Missing:GIN', 'MOUSE_LINE:GIN']

# %%
# use sherlok to annotate each curated neuron mention in neuroelectro
annot_vec = []
dict_list = []
for index, row in table.iterrows():
    neuron_name_orig = row['NeuronLongName']
    strain = unicode(row['Strain'])
    # if no neuron long name, use neurolex neuron name (should always be available)
    if pd.isnull(neuron_name_orig):
        neuron_name_orig = row['NeuronName']
        
    # hack for adding strain annotations, since not in neuroNER
    neuron_name = add_animal_strain_to_neuron(neuron_name_orig, strain)
    
    # annotate using sherlok
    r = s.annotate(neuron_name)
    cleaned_annotations = _cleanup(r.annotations, neuron_name)
    
    if check_strain(neuron_name):
        cleaned_annotations.append(check_strain(neuron_name))
        for c in cleaned_annotations:
            if c.startswith('NCBI_GENE'):
                cleaned_annotations.remove(c)
    short_annots = _normalize(cleaned_annotations, shorten = True)
    temp_dict = annots_to_dict(cleaned_annotations)
    temp_dict['neuron_name'] = neuron_name
    temp_dict['neuron_name_orig'] = neuron_name_orig
    temp_dict['short_name'] = short_annots
    temp_dict['annotations'] = cleaned_annotations
    temp_dict['Index'] = index
    dict_list.append(temp_dict)

#     f = format_annots(neuron_name, r.annotations)
#     annot_vec.append((neuron_name, f))

# %%
dict_list[4]
# Out:
# {'Index': 1093,
#  'annotations': [u'UNKN_REGION:3442',
#   'HBP_PROJECTION:22',
#   u'HBP_MORPHOLOGY:0000001'],
#  'neuron_name': 'secondary motor cortex corticospinal pyramidal cells',
#  'neuron_name_orig': 'secondary motor cortex corticospinal pyramidal cells',
#  'region': 'secondary motor cortex',
#  'shape': 'Pyr',
#  'short_name': 'secondary motor cortex CSp Pyr'}

# %%
col_names = [n[1] for n in name_spaces]
col_names.append('projection')

df = pd.DataFrame.from_records(dict_list, index = 'Index')
df

table[0:4]
# Out:
#                                                    Title      Pmid  PubYear  \
# Index
# 1010   GluN2D-containing NMDA receptors-mediate synap...  25859181     2015
# 1011   GluN2D-containing NMDA receptors-mediate synap...  25859181     2015
# 1012   GluN2D-containing NMDA receptors-mediate synap...  25859181     2015
# 1018   Rac1 and rac3 GTPases control synergistically ...  23258346     2014
#
#         LastAuthor  ArticleID  TableID                      NeuronName  \
# Index
# 1010      Monyer H      85644    27502                           Other
# 1011      Monyer H      85644    27502                           Other
# 1012      Monyer H      85644    27502                           Other
# 1018   de Curtis I      88539    36200  Hippocampus CA3 pyramidal cell
#
#                                      NeuronLongName            BrainRegion  \
# Index
# 1010   Hippocampus GluN2D-EGFP-positive interneuron                    NaN
# 1011   Hippocampus GluN2D-EGFP-positive interneuron                    NaN
# 1012   Hippocampus GluN2D-EGFP-positive interneuron                    NaN
# 1018                                            NaN  Hippocampal formation
#
#       MetadataCurated         ...          ADP amplitude access resistance  \
# Index                         ...
# 1010             True         ...                    NaN               NaN
# 1011             True         ...                    NaN               NaN
# 1012             True         ...                    NaN               NaN
# 1018             True         ...                    NaN               NaN
#
#       spike decay time fast AHP duration cell diameter  slow AHP duration  \
# Index
# 1010               NaN               NaN           NaN                NaN
# 1011               NaN               NaN           NaN                NaN
# 1012               NaN               NaN           NaN                NaN
# 1018               NaN               NaN           NaN                NaN
#
#        medium AHP amplitude  cell surface area  ADP duration  \
# Index
# 1010                    NaN                NaN           NaN
# 1011                    NaN                NaN           NaN
# 1012                    NaN                NaN           NaN
# 1018                    NaN                NaN           NaN
#
#        medium AHP duration
# Index
# 1010                   NaN
# 1011                   NaN
# 1012                   NaN
# 1018                   NaN
#
# [4 rows x 72 columns]

# %%
table = table.join(df)

# %%
table.to_csv('df.csv', sep='\t', encoding='utf-8')

# %%
table.head()
# Out:
#                                                    Title      Pmid  PubYear  \
# Index
# 1010   GluN2D-containing NMDA receptors-mediate synap...  25859181     2015
# 1011   GluN2D-containing NMDA receptors-mediate synap...  25859181     2015
# 1012   GluN2D-containing NMDA receptors-mediate synap...  25859181     2015
# 1018   Rac1 and rac3 GTPases control synergistically ...  23258346     2014
# 1093   Multiple layer 5 pyramidal cell subtypes relay...  23551921     2014
#
#         LastAuthor  ArticleID  TableID                          NeuronName  \
# Index
# 1010      Monyer H      85644    27502                               Other
# 1011      Monyer H      85644    27502                               Other
# 1012      Monyer H      85644    27502                               Other
# 1018   de Curtis I      88539    36200      Hippocampus CA3 pyramidal cell
# 1093   Kawaguchi Y      88453    35997  Neocortex pyramidal cell layer 5-6
#
#                                           NeuronLongName  \
# Index
# 1010        Hippocampus GluN2D-EGFP-positive interneuron
# 1011        Hippocampus GluN2D-EGFP-positive interneuron
# 1012        Hippocampus GluN2D-EGFP-positive interneuron
# 1018                                                 NaN
# 1093   secondary motor cortex corticospinal pyramidal...
#
#                  BrainRegion MetadataCurated               ...                \
# Index                                                      ...
# 1010                     NaN            True               ...
# 1011                     NaN            True               ...
# 1012                     NaN            True               ...
# 1018   Hippocampal formation            True               ...
# 1093               Isocortex            True               ...
#
#                                              annotations ephys gene layer  \
# Index
# 1010   [ABA_REGION:1080, HBP_NEUROTRANSMITTER:0000004...   NaN  NaN   NaN
# 1011   [ABA_REGION:1080, HBP_NEUROTRANSMITTER:0000004...   NaN  NaN   NaN
# 1012   [ABA_REGION:1080, HBP_NEUROTRANSMITTER:0000004...   NaN  NaN   NaN
# 1018            [ABA_REGION:463, HBP_MORPHOLOGY:0000001]   NaN  NaN   NaN
# 1093   [UNKN_REGION:3442, HBP_PROJECTION:22, HBP_MORP...   NaN  NaN   NaN
#
#       line                                        neuron_name  \
# Index
# 1010   NaN       Hippocampus GluN2D-EGFP-positive interneuron
# 1011   NaN       Hippocampus GluN2D-EGFP-positive interneuron
# 1012   NaN       Hippocampus GluN2D-EGFP-positive interneuron
# 1018   NaN                     Hippocampus CA3 pyramidal cell
# 1093   NaN  secondary motor cortex corticospinal pyramidal...
#
#                                         neuron_name_orig  \
# Index
# 1010        Hippocampus GluN2D-EGFP-positive interneuron
# 1011        Hippocampus GluN2D-EGFP-positive interneuron
# 1012        Hippocampus GluN2D-EGFP-positive interneuron
# 1018                      Hippocampus CA3 pyramidal cell
# 1093   secondary motor cortex corticospinal pyramidal...
#
#                        region  shape                      short_name
# Index
# 1010                      HIP    NaN      HIP glu N2D-EGFP- positive
# 1011                      HIP    NaN      HIP glu N2D-EGFP- positive
# 1012                      HIP    NaN      HIP glu N2D-EGFP- positive
# 1018                      CA3    Pyr                         CA3 Pyr
# 1093   secondary motor cortex    Pyr  secondary motor cortex CSp Pyr
#
# [5 rows x 82 columns]

# %%
# load in csv of Design.csv dataset

gene_exp_path = '/home/stripathy/brainCellTypeSpecificGenes/data/Design.tsv'
gene_exp_table = pd.read_csv(gene_exp_path, sep='\t', index_col = 0, header=0)

# %%
gene_exp_table.tail()
# Out:
#                                   MajorType JustPyra GabaDeep PyramidalDeep  \
# Cell.Type..Samples
# GSM1698225,GSM1698226,GSM1698227     Neuron      NaN      NaN           NaN
# GSM1698228,GSM16982289,GSM1698230    Neuron      NaN      NaN           NaN
# GSM1698231,GSM1698232,GSM1698233     Neuron      NaN      NaN           NaN
# GSM1698237,GSM1698238,GSM1698239       Glia      NaN      NaN           NaN
# GSM1698234,GSM1698235,GSM1698236       Glia      NaN      NaN           NaN
#
#                                   Neurotransmitter1 ShinyNames  ShinySubtypes  \
# Cell.Type..Samples
# GSM1698225,GSM1698226,GSM1698227                NaN        NaN            NaN
# GSM1698228,GSM16982289,GSM1698230               NaN        NaN            NaN
# GSM1698231,GSM1698232,GSM1698233                NaN        NaN            NaN
# GSM1698237,GSM1698238,GSM1698239                NaN        NaN            NaN
# GSM1698234,GSM1698235,GSM1698236                NaN        NaN            NaN
#
#                                   CellType forContanim Normalize2.0  \
# Cell.Type..Samples
# GSM1698225,GSM1698226,GSM1698227       NaN   Pyramidal            T
# GSM1698228,GSM16982289,GSM1698230      NaN   Pyramidal            T
# GSM1698231,GSM1698232,GSM1698233       NaN   Gabaergic            T
# GSM1698237,GSM1698238,GSM1698239       NaN       Oligo            T
# GSM1698234,GSM1698235,GSM1698236       NaN   Astrocyte            T
#
#                                       ...      Method RNA.isolation.method  \
# Cell.Type..Samples                    ...
# GSM1698225,GSM1698226,GSM1698227      ...        TRAP                  NaN
# GSM1698228,GSM16982289,GSM1698230     ...        TRAP                  NaN
# GSM1698231,GSM1698232,GSM1698233      ...        TRAP                  NaN
# GSM1698237,GSM1698238,GSM1698239      ...        TRAP                  NaN
# GSM1698234,GSM1698235,GSM1698236      ...        TRAP                  NaN
#
#                                   RNA.amplification.and.labeling.method  \
# Cell.Type..Samples
# GSM1698225,GSM1698226,GSM1698227                                    NaN
# GSM1698228,GSM16982289,GSM1698230                                   NaN
# GSM1698231,GSM1698232,GSM1698233                                    NaN
# GSM1698237,GSM1698238,GSM1698239                                    NaN
# GSM1698234,GSM1698235,GSM1698236                                    NaN
#
#                                   Platform             Reference      PMID  \
# Cell.Type..Samples
# GSM1698225,GSM1698226,GSM1698227   GPL1261  Shrestha et al. 2015  26371510
# GSM1698228,GSM16982289,GSM1698230  GPL1261  Shrestha et al. 2015  26371510
# GSM1698231,GSM1698232,GSM1698233   GPL1261  Shrestha et al. 2015  26371510
# GSM1698237,GSM1698238,GSM1698239   GPL1261  Shrestha et al. 2015  26371510
# GSM1698234,GSM1698235,GSM1698236   GPL1261  Shrestha et al. 2015  26371510
#
#                                   SharePermit                 Notes  \
# Cell.Type..Samples
# GSM1698225,GSM1698226,GSM1698227            T  shreejoy wanted them
# GSM1698228,GSM16982289,GSM1698230           T  shreejoy wanted them
# GSM1698231,GSM1698232,GSM1698233            T  shreejoy wanted them
# GSM1698237,GSM1698238,GSM1698239            T  shreejoy wanted them
# GSM1698234,GSM1698235,GSM1698236            T  shreejoy wanted them
#
#                                   MouseStrain ReporterGene
# Cell.Type..Samples
# GSM1698225,GSM1698226,GSM1698227          NaN          NaN
# GSM1698228,GSM16982289,GSM1698230         NaN          NaN
# GSM1698231,GSM1698232,GSM1698233          NaN          NaN
# GSM1698237,GSM1698238,GSM1698239          NaN          NaN
# GSM1698234,GSM1698235,GSM1698236          NaN          NaN
#
# [5 rows x 29 columns]

# %%
import re

# use sherlok to annotate each curated neuron mention in neuroelectro
#annot_vec = []
gene_dict_list = []
for index, row in gene_exp_table.iterrows():
    neuron_name = row['neuroNER Inferred Properties']
    
    # if no neuron long name, just move on
    if pd.isnull(neuron_name):
        temp_dict = {}
        temp_dict['annotations'] = []
        temp_dict['Index'] = index
        temp_dict['short_name'] = ''
        temp_dict['neuron_name'] = ''
        gene_dict_list.append(temp_dict)
        continue
        # neuron_name = row['NeuronName']
    
    mouse_line_match = re.search('from .+ mouse line', neuron_name)
    if mouse_line_match:
        strain_annotation = check_strain(neuron_name)
        neuron_name = re.sub('from .+ mouse line', '', neuron_name)
    
    # annotate using sherlok
    r = s.annotate(neuron_name)
    cleaned_annotations = _cleanup(r.annotations, neuron_name)
    if mouse_line_match:
        cleaned_annotations.append(strain_annotation)
        for c in cleaned_annotations:
            if c.startswith('NCBI_GENE'):
                cleaned_annotations.remove(c)
    short_annots = _normalize(cleaned_annotations, shorten = True)
    temp_dict = annots_to_dict(cleaned_annotations)
    temp_dict['short_name'] = short_annots
    temp_dict['neuron_name'] = neuron_name
    temp_dict['annotations'] = cleaned_annotations
    temp_dict['Index'] = index
    gene_dict_list.append(temp_dict)

#     f = format_annots(neuron_name, r.annotations)
#     annot_vec.append((neuron_name, f))

# %%
df_gene = pd.DataFrame.from_records(gene_dict_list, index = 'Index')
gene_exp_table = gene_exp_table.join(df_gene)

# %%
gene_exp_table.to_csv('df_gene.csv', sep='\t', encoding='utf-8')

# %%
for index, row in gene_exp_table.iterrows():
    curr_list = row
    sim_vec = []
    sim_val_vec = []
    for d in dict_list:
        sim = similarity2(curr_list['annotations'], d['annotations'], symmetric = False, use_inter_similarity = False, )
        sim_vec.append(sim)
        sim_val_vec.append(sim[0])
    sim_val_vec
    inds = sorted(range(len(sim_val_vec)),key=lambda x:sim_val_vec[x], reverse = True)
    print 'target name -> %s' % curr_list['short_name']
    #print curr_list['annotations']
    for i in range(0,20):
        print 'match value: %.2f, best match: %s' % (sim_val_vec[inds[i]], dict_list[inds[i]]['short_name'])
        #print dict_list[inds[i]]['annotations']
    print '\n'
# Out:
# target name -> Isocortex L5a Etv1 ST Pyr
# match value: 0.68, best match: SSp-bfd Pyr L5a
# match value: 0.68, best match: L5a SS barrel column small tuft Pyr
# match value: 0.68, best match: L5a somatosensory SSp-bfd Pyr
# match value: 0.68, best match: L5a somatosensory SSp-bfd Pyr
# match value: 0.68, best match: L5a somatosensory SSp-bfd Pyr
# match value: 0.68, best match: primary somatosensory SSp-bfd L5a Pyr
# match value: 0.68, best match: somatosensory SSp-bfd L5a Pyr
# match value: 0.65, best match: Isocortex L5 Pyr
# match value: 0.65, best match: Isocortex L5 large Pyr
# match value: 0.65, best match: L5 Isocortex Pyr
# match value: 0.65, best match: Isocortex L5 Pyr
# match value: 0.62, best match: ORB L5 large Pyr
# match value: 0.62, best match: VIS L5 R S tall Pyr
# match value: 0.62, best match: VIS L5 B tall Pyr
# match value: 0.62, best match: VIS L5 R S short Pyr
# match value: 0.62, best match: MOp L5 CThal Pyr
# match value: 0.62, best match: MOp L5 CSp Pyr
# match value: 0.62, best match: MOp L5 CCo Pyr
# match value: 0.62, best match: MOp L5 CStr Pyr
# match value: 0.62, best match: L5 frontal Pyr projecting PERI CTX
#
#
# target name -> Isocortex L5b Colgalt2 TT Pyr
# match value: 0.83, best match: SSs L5b CSp TT large Pyr
# match value: 0.83, best match: MOp L5b CSp TT large Pyr
# match value: 0.83, best match: MOp L5b CSp TT large Pyr
# match value: 0.83, best match: MOp L5b CSp TT large Pyr
# match value: 0.77, best match: L5 VIS large TT Pyr
# match value: 0.77, best match: SS L5 TT Pyr
# match value: 0.68, best match: SS L5b Pyr
# match value: 0.68, best match: SSp-bfd Pyr L5b
# match value: 0.68, best match: L5b SS barrel column extensive tuft Pyr
# match value: 0.68, best match: primary somatosensory SSp-bfd L5b Pyr R S
# match value: 0.68, best match: primary somatosensory SSp-bfd L5b Pyr I B
# match value: 0.68, best match: somatosensory SSp-bfd L5b Pyr
# match value: 0.65, best match: Isocortex L5 Pyr
# match value: 0.65, best match: Isocortex L5 large Pyr
# match value: 0.65, best match: L5 Isocortex Pyr
# match value: 0.65, best match: Isocortex L5 Pyr
# match value: 0.62, best match: ORB L5 large Pyr
# match value: 0.62, best match: VIS L5 R S tall Pyr
# match value: 0.62, best match: VIS L5 B tall Pyr
# match value: 0.62, best match: VIS L5 R S short Pyr
#
#
# target name -> Isocortex L6 Ntsr1 Pyr
# match value: 0.81, best match: SSp-bfd CThal Pyr L6 with F AHP
# match value: 0.81, best match: SSp-bfd non- CThal Pyr L6 with medium AHP
# match value: 0.81, best match: L6 SS Pyr
# match value: 0.81, best match: L6 SS barrel column short Pyr
# match value: 0.81, best match: ORB L6 small Pyr
# match value: 0.81, best match: anterior ACA L6 Pyr
# match value: 0.73, best match: Isocortex Pyr L5-6
# match value: 0.73, best match: Isocortex Pyr L5-6
# match value: 0.73, best match: Isocortex Pyr L5-6
# match value: 0.70, best match: ORB L5-6 Pyr
# match value: 0.70, best match: SSp-bfd L6a CCo Pyr with infragranular arborization axons
# match value: 0.70, best match: L6a SSp-bfd Pyr CThal with large terminal arbors
# match value: 0.70, best match: SS L5-6 Pyr
# match value: 0.70, best match: ORB L5-6 Pyr
# match value: 0.70, best match: medial ORB L5-6 Low-Threshold Calcium S Pyr
# match value: 0.70, best match: medial ORB L5-6 Non-Low-Threshold Calcium S Pyr
# match value: 0.65, best match: L6 MO NPyr Slc17a7
# match value: 0.65, best match: SS L6 Mart
# match value: 0.65, best match: VISp L6 Antidromic Corticofugal Antidromic Corticofugal
# match value: 0.65, best match: VISp L6 Non-antidromic Corticofugal
#
#
# target name -> Isocortex Cck
# match value: 0.93, best match: ORB L2-3 NPyr Cck R S
# match value: 0.93, best match: ORB L2-3 NPyr Cck gaba B S
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L2-3 LT S
# match value: 0.60, best match: Isocortex L5 Pyr
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L5 large Pyr
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex Pyr L2-3
# match value: 0.60, best match: Isocortex Pyr L2-3
# match value: 0.60, best match: Isocortex Pyr L5-6
# match value: 0.60, best match: Isocortex L2-3 gaba L S subtype 1 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba L NF F S Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba L S subtype 2 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba B NAd Ad subtype 2 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba F Ad Htr3a
#
#
# target name -> BS Chat ACh motor
# match value: 0.38, best match: SOCm ventral
# match value: 0.38, best match: SOCm dorsal
# match value: 0.38, best match: SOCm ventral
# match value: 0.38, best match: SOCm dorsal
# match value: 0.38, best match: LC neuropeptide S expressing
# match value: 0.38, best match: LC NAdr
# match value: 0.38, best match: LC
# match value: 0.38, best match: LC NAdr
# match value: 0.38, best match: silent PG caudalis caudalis
# match value: 0.38, best match: Spontaneuous S PG caudalis caudalis
# match value: 0.38, best match: LC NAdr
# match value: 0.38, best match: SUT
# match value: 0.32, best match: BLA principal with input from ORB CTX
# match value: 0.32, best match: SUB Pyr projecting to RSP CTX
# match value: 0.32, best match: SUB Pyr projecting to lateral entorhinal cortex CTX
# match value: 0.32, best match: SUB Pyr projecting to medial entorhinal cortex CTX
# match value: 0.32, best match: SUB Pyr projecting to ORB CTX
# match value: 0.32, best match: L2-3 frontal Pyr projecting PERI CTX
# match value: 0.32, best match: L5 frontal Pyr projecting PERI CTX
# match value: 0.32, best match: medial entorihinal CTX L2 stellate
#
#
# target name -> basal forebrain Chat ACh
# match value: 0.67, best match: basal forebrain Chat early S
# match value: 0.67, best match: basal forebrain Chat L S
# match value: 0.67, best match: basal forebrain ACh
# match value: 0.33, best match: Basalis nucleus ACh
# match value: 0.33, best match: CP ACh
# match value: 0.33, best match: CP ACh
# match value: 0.33, best match: CP ACh
# match value: 0.33, best match: CP ACh
# match value: 0.33, best match: Basalis nucleus ACh
# match value: 0.33, best match: Basalis nucleus ACh
# match value: 0.33, best match: dorsolateral pontine ACh rostral subcoeruleus
# match value: 0.33, best match: medial septum diagonal band ACh Slow S
# match value: 0.33, best match: CP aspiny ACh
# match value: 0.33, best match: CA1 ACh dependent plateau potentials Pyr
# match value: 0.33, best match: nucleus basalis ventral pallidal region Chat
# match value: 0.33, best match: nucleus basalis ventral pallidal region Chat
# match value: 0.33, best match: CP ACh
# match value: 0.33, best match: Basalis nucleus ACh
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
#
#
# target name -> spinal cord Chat ACh
# match value: 0.40, best match: Basalis nucleus ACh
# match value: 0.40, best match: basal forebrain Chat early S
# match value: 0.40, best match: basal forebrain Chat L S
# match value: 0.40, best match: CP ACh
# match value: 0.40, best match: CP ACh
# match value: 0.40, best match: CP ACh
# match value: 0.40, best match: CP ACh
# match value: 0.40, best match: Basalis nucleus ACh
# match value: 0.40, best match: Basalis nucleus ACh
# match value: 0.40, best match: dorsolateral pontine ACh rostral subcoeruleus
# match value: 0.40, best match: medial septum diagonal band ACh Slow S
# match value: 0.40, best match: CP aspiny ACh
# match value: 0.40, best match: CA1 ACh dependent plateau potentials Pyr
# match value: 0.40, best match: nucleus basalis ventral pallidal region Chat
# match value: 0.40, best match: nucleus basalis ventral pallidal region Chat
# match value: 0.40, best match: CP ACh
# match value: 0.40, best match: basal forebrain ACh
# match value: 0.40, best match: Basalis nucleus ACh
# match value: 0.20, best match: spinal cord Motor
# match value: 0.20, best match: spinal cord ventral horn motor alpha
#
#
# target name -> CP Chat ACh giant
# match value: 0.71, best match: CP ACh
# match value: 0.71, best match: CP ACh
# match value: 0.71, best match: CP ACh
# match value: 0.71, best match: CP ACh
# match value: 0.71, best match: CP aspiny ACh
# match value: 0.71, best match: CP ACh
# match value: 0.43, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.43, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
# match value: 0.43, best match: CP Pvalb Htr3a F S gaba
# match value: 0.43, best match: CP medium spiny
# match value: 0.43, best match: CP Pvalb R S gaba
# match value: 0.43, best match: CP Pvalb B gaba
# match value: 0.43, best match: CP Pvalb I B gaba
# match value: 0.43, best match: CP medium spiny
# match value: 0.43, best match: CP Gfap
# match value: 0.43, best match: CP gaba F S
# match value: 0.43, best match: CP medium spiny
# match value: 0.43, best match: CP Th
# match value: 0.43, best match: CP Th
# match value: 0.43, best match: CP Npy Sst Nos1 Nos1 GABAergic plateau-depolarization LT S
#
#
# target name -> Isocortex Cort
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L2-3 LT S
# match value: 0.60, best match: Isocortex L5 Pyr
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L5 large Pyr
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex Pyr L2-3
# match value: 0.60, best match: Isocortex Pyr L2-3
# match value: 0.60, best match: Isocortex Pyr L5-6
# match value: 0.60, best match: Isocortex L2-3 gaba L S subtype 1 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba L NF F S Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba L S subtype 2 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba B NAd Ad subtype 2 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba F Ad Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba B NAd Ad subtype 1 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba I S bipolar Htr3a
#
#
# target name -> CP Drd1 medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium -sized spiny projection
# match value: 0.71, best match: CP medium -sized spiny projection
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny gaba
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
#
#
# target name -> CP Drd2 medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium -sized spiny projection
# match value: 0.71, best match: CP medium -sized spiny projection
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny gaba
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
# match value: 0.71, best match: CP medium spiny
#
#
# target name -> CB Grm2 expresing Golgi
# match value: 0.71, best match: CB Golgi
# match value: 0.71, best match: CB Golgi
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB VERM II-VIII lobules Purkinje
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: Deep CB Nucleus non- gaba small
# match value: 0.43, best match: Deep CB Nucleus non- gaba large
# match value: 0.43, best match: Deep CB Nucleus gaba Gad1 small
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: Somatosensory CB C3 granule
#
#
# target name -> CB Grp unipolar brush
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: CB Golgi
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB VERM II-VIII lobules Purkinje
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: Deep CB Nucleus non- gaba small
# match value: 0.43, best match: Deep CB Nucleus non- gaba large
# match value: 0.43, best match: Deep CB Nucleus gaba Gad1 small
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Golgi
# match value: 0.43, best match: Somatosensory CB C3 granule
#
#
# target name -> CB Lypd6 basket and stellate
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB granule
# match value: 0.33, best match: CB Golgi
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB VERM II-VIII lobules Purkinje
# match value: 0.33, best match: CB granule
# match value: 0.33, best match: Deep CB Nucleus non- gaba small
# match value: 0.33, best match: Deep CB Nucleus non- gaba large
# match value: 0.33, best match: Deep CB Nucleus gaba Gad1 small
# match value: 0.33, best match: CB granule
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB Purkinje
# match value: 0.33, best match: CB Golgi
# match value: 0.33, best match: Somatosensory CB C3 granule
#
#
# target name -> CB Neurod1 granule
# match value: 0.71, best match: CB granule
# match value: 0.71, best match: CB granule
# match value: 0.71, best match: CB granule
# match value: 0.71, best match: Somatosensory CB C3 granule
# match value: 0.71, best match: CB granule
# match value: 0.71, best match: CB granule
# match value: 0.71, best match: CB granule
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Golgi
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB VERM II-VIII lobules Purkinje
# match value: 0.43, best match: Deep CB Nucleus non- gaba small
# match value: 0.43, best match: Deep CB Nucleus non- gaba large
# match value: 0.43, best match: Deep CB Nucleus gaba Gad1 small
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name -> CB Pcp2 Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB VERM II-VIII lobules Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.66, best match: Densely Purkinje innerverted, FL targeting, gly
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: CB Golgi
# match value: 0.43, best match: CB granule
#
#
# target name -> Isocortex Pnoc
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L2-3 LT S
# match value: 0.60, best match: Isocortex L5 Pyr
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L5 large Pyr
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex Pyr L2-3
# match value: 0.60, best match: Isocortex Pyr L2-3
# match value: 0.60, best match: Isocortex Pyr L5-6
# match value: 0.60, best match: Isocortex L2-3 gaba L S subtype 1 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba L NF F S Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba L S subtype 2 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba B NAd Ad subtype 2 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba F Ad Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba B NAd Ad subtype 1 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba I S bipolar Htr3a
#
#
# target name -> CB Sept4 Bergmann
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: CB Golgi
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB VERM II-VIII lobules Purkinje
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: Deep CB Nucleus non- gaba small
# match value: 0.43, best match: Deep CB Nucleus non- gaba large
# match value: 0.43, best match: Deep CB Nucleus gaba Gad1 small
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Purkinje
# match value: 0.43, best match: CB Golgi
# match value: 0.43, best match: Somatosensory CB C3 granule
#
#
# target name -> CB
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB granule
# match value: 1.00, best match: CB Golgi
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB VERM II-VIII lobules Purkinje
# match value: 1.00, best match: CB granule
# match value: 1.00, best match: Deep CB Nucleus non- gaba small
# match value: 1.00, best match: Deep CB Nucleus non- gaba large
# match value: 1.00, best match: Deep CB Nucleus gaba Gad1 small
# match value: 1.00, best match: CB granule
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB Purkinje
# match value: 1.00, best match: CB Golgi
# match value: 1.00, best match: Somatosensory CB C3 granule
#
#
# target name -> Isocortex
# match value: 1.00, best match: Isocortex basket
# match value: 1.00, best match: Isocortex L4 stellate
# match value: 1.00, best match: Isocortex L2-3 LT S
# match value: 1.00, best match: Isocortex L5 Pyr
# match value: 1.00, best match: Isocortex basket
# match value: 1.00, best match: Isocortex basket
# match value: 1.00, best match: Isocortex L4 stellate
# match value: 1.00, best match: Isocortex L4 stellate
# match value: 1.00, best match: Isocortex L5 large Pyr
# match value: 1.00, best match: Isocortex basket
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L5-6
# match value: 1.00, best match: Isocortex L2-3 gaba L S subtype 1 Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba L NF F S Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba L S subtype 2 Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba B NAd Ad subtype 2 Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba F Ad Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba B NAd Ad subtype 1 Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba I S bipolar Htr3a
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name -> MO L5 CCo Pyr
# match value: 0.98, best match: MOp L5 CCo Pyr
# match value: 0.96, best match: SSp L5 CCo projecting Pyr
# match value: 0.67, best match: SSp-bfd L6a CCo Pyr with infragranular arborization axons
# match value: 0.56, best match: L5 MO Pyr
# match value: 0.56, best match: L4 -projecting L6 inhibitory CCo infragranular laminae laminae of the SSp-bfd CTX
# match value: 0.56, best match: CCo L6 -projecting, L6 inhibitory infragranular laminae laminae of the SSp-bfd CTX
# match value: 0.54, best match: MOp L5 CThal Pyr
# match value: 0.54, best match: MOp L5 CSp Pyr
# match value: 0.54, best match: MOp L5 CStr Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.54, best match: Isocortex L5 large Pyr
# match value: 0.54, best match: L5 Isocortex Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.52, best match: ORB L5 large Pyr
# match value: 0.52, best match: VIS L5 R S tall Pyr
# match value: 0.52, best match: VIS L5 B tall Pyr
# match value: 0.52, best match: VIS L5 R S short Pyr
# match value: 0.52, best match: L5 frontal Pyr projecting PERI CTX
# match value: 0.52, best match: R S , L5 Pyr of SS  YFP Thy1-YFP
# match value: 0.52, best match: SS L5 apical Pyr
#
#
# target name -> MO L5 CCo Pyr
# match value: 0.98, best match: MOp L5 CCo Pyr
# match value: 0.96, best match: SSp L5 CCo projecting Pyr
# match value: 0.67, best match: SSp-bfd L6a CCo Pyr with infragranular arborization axons
# match value: 0.56, best match: L5 MO Pyr
# match value: 0.56, best match: L4 -projecting L6 inhibitory CCo infragranular laminae laminae of the SSp-bfd CTX
# match value: 0.56, best match: CCo L6 -projecting, L6 inhibitory infragranular laminae laminae of the SSp-bfd CTX
# match value: 0.54, best match: MOp L5 CThal Pyr
# match value: 0.54, best match: MOp L5 CSp Pyr
# match value: 0.54, best match: MOp L5 CStr Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.54, best match: Isocortex L5 large Pyr
# match value: 0.54, best match: L5 Isocortex Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.52, best match: ORB L5 large Pyr
# match value: 0.52, best match: VIS L5 R S tall Pyr
# match value: 0.52, best match: VIS L5 B tall Pyr
# match value: 0.52, best match: VIS L5 R S short Pyr
# match value: 0.52, best match: L5 frontal Pyr projecting PERI CTX
# match value: 0.52, best match: R S , L5 Pyr of SS  YFP Thy1-YFP
# match value: 0.52, best match: SS L5 apical Pyr
#
#
# target name -> MO L5 CCo Pyr
# match value: 0.98, best match: MOp L5 CCo Pyr
# match value: 0.96, best match: SSp L5 CCo projecting Pyr
# match value: 0.67, best match: SSp-bfd L6a CCo Pyr with infragranular arborization axons
# match value: 0.56, best match: L5 MO Pyr
# match value: 0.56, best match: L4 -projecting L6 inhibitory CCo infragranular laminae laminae of the SSp-bfd CTX
# match value: 0.56, best match: CCo L6 -projecting, L6 inhibitory infragranular laminae laminae of the SSp-bfd CTX
# match value: 0.54, best match: MOp L5 CThal Pyr
# match value: 0.54, best match: MOp L5 CSp Pyr
# match value: 0.54, best match: MOp L5 CStr Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.54, best match: Isocortex L5 large Pyr
# match value: 0.54, best match: L5 Isocortex Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.52, best match: ORB L5 large Pyr
# match value: 0.52, best match: VIS L5 R S tall Pyr
# match value: 0.52, best match: VIS L5 B tall Pyr
# match value: 0.52, best match: VIS L5 R S short Pyr
# match value: 0.52, best match: L5 frontal Pyr projecting PERI CTX
# match value: 0.52, best match: R S , L5 Pyr of SS  YFP Thy1-YFP
# match value: 0.52, best match: SS L5 apical Pyr
#
#
# target name -> MO L5 CSp Pyr
# match value: 0.98, best match: MOp L5 CSp Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.89, best match: SSs L5b CSp TT large Pyr
# match value: 0.69, best match: MOp CSp Pyr
# match value: 0.56, best match: L5 MO Pyr
# match value: 0.55, best match: secondary motor cortex CSp Pyr
# match value: 0.54, best match: MOp L5 CThal Pyr
# match value: 0.54, best match: MOp L5 CCo Pyr
# match value: 0.54, best match: MOp L5 CStr Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.54, best match: Isocortex L5 large Pyr
# match value: 0.54, best match: L5 Isocortex Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.52, best match: ORB L5 large Pyr
# match value: 0.52, best match: VIS L5 R S tall Pyr
# match value: 0.52, best match: VIS L5 B tall Pyr
# match value: 0.52, best match: VIS L5 R S short Pyr
# match value: 0.52, best match: L5 frontal Pyr projecting PERI CTX
#
#
# target name -> MO L5 CSp Pyr
# match value: 0.98, best match: MOp L5 CSp Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.89, best match: SSs L5b CSp TT large Pyr
# match value: 0.69, best match: MOp CSp Pyr
# match value: 0.56, best match: L5 MO Pyr
# match value: 0.55, best match: secondary motor cortex CSp Pyr
# match value: 0.54, best match: MOp L5 CThal Pyr
# match value: 0.54, best match: MOp L5 CCo Pyr
# match value: 0.54, best match: MOp L5 CStr Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.54, best match: Isocortex L5 large Pyr
# match value: 0.54, best match: L5 Isocortex Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.52, best match: ORB L5 large Pyr
# match value: 0.52, best match: VIS L5 R S tall Pyr
# match value: 0.52, best match: VIS L5 B tall Pyr
# match value: 0.52, best match: VIS L5 R S short Pyr
# match value: 0.52, best match: L5 frontal Pyr projecting PERI CTX
#
#
# target name -> MO L5 CSp Pyr
# match value: 0.98, best match: MOp L5 CSp Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.91, best match: MOp L5b CSp TT large Pyr
# match value: 0.89, best match: SSs L5b CSp TT large Pyr
# match value: 0.69, best match: MOp CSp Pyr
# match value: 0.56, best match: L5 MO Pyr
# match value: 0.55, best match: secondary motor cortex CSp Pyr
# match value: 0.54, best match: MOp L5 CThal Pyr
# match value: 0.54, best match: MOp L5 CCo Pyr
# match value: 0.54, best match: MOp L5 CStr Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.54, best match: Isocortex L5 large Pyr
# match value: 0.54, best match: L5 Isocortex Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.52, best match: ORB L5 large Pyr
# match value: 0.52, best match: VIS L5 R S tall Pyr
# match value: 0.52, best match: VIS L5 B tall Pyr
# match value: 0.52, best match: VIS L5 R S short Pyr
# match value: 0.52, best match: L5 frontal Pyr projecting PERI CTX
#
#
# target name -> VIS L5 CTect Pyr
# match value: 0.56, best match: VIS L5 R S tall Pyr
# match value: 0.56, best match: VIS L5 B tall Pyr
# match value: 0.56, best match: VIS L5 R S short Pyr
# match value: 0.56, best match: L5 VIS large TT Pyr
# match value: 0.56, best match: VIS L5 R S Pyr
# match value: 0.56, best match: VIS L5 B Pyr
# match value: 0.56, best match: associative parietal and VIS L5 Pyr projecting to superior colliculus
# match value: 0.56, best match: associative parietal and VIS L5 Pyr projecting to contralateral CTX
# match value: 0.56, best match: associative parietal and VIS L5 Pyr projecting to contralateral CTX
# match value: 0.56, best match: associative parietal and VIS L5 Pyr projecting to superior colliculus
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.54, best match: Isocortex L5 large Pyr
# match value: 0.54, best match: L5 Isocortex Pyr
# match value: 0.54, best match: Isocortex L5 Pyr
# match value: 0.52, best match: ORB L5 large Pyr
# match value: 0.52, best match: MOp L5 CThal Pyr
# match value: 0.52, best match: MOp L5 CSp Pyr
# match value: 0.52, best match: MOp L5 CCo Pyr
# match value: 0.52, best match: MOp L5 CStr Pyr
# match value: 0.52, best match: L5 frontal Pyr projecting PERI CTX
#
#
# target name -> ACA L6 CThal Ad Pyr
# match value: 0.96, best match: SSp-bfd CThal Pyr L6 with F AHP
# match value: 0.96, best match: SSp-bfd non- CThal Pyr L6 with medium AHP
# match value: 0.89, best match: L6a SSp-bfd Pyr CThal with large terminal arbors
# match value: 0.67, best match: MOp L5 CThal Pyr
# match value: 0.67, best match: SSp L5 CThal projecting Pyr
# match value: 0.56, best match: anterior ACA L6 Pyr
# match value: 0.55, best match: L5 frontal Pyr CThal projecting
# match value: 0.52, best match: L6 SS Pyr
# match value: 0.52, best match: L6 SS barrel column short Pyr
# match value: 0.52, best match: ORB L6 small Pyr
# match value: 0.47, best match: Isocortex Pyr L5-6
# match value: 0.47, best match: Isocortex Pyr L5-6
# match value: 0.47, best match: Isocortex Pyr L5-6
# match value: 0.45, best match: ORB L5-6 Pyr
# match value: 0.45, best match: SSp-bfd L6a CCo Pyr with infragranular arborization axons
# match value: 0.45, best match: SS L5-6 Pyr
# match value: 0.45, best match: ORB L5-6 Pyr
# match value: 0.45, best match: medial ORB L5-6 Low-Threshold Calcium S Pyr
# match value: 0.45, best match: medial ORB L5-6 Non-Low-Threshold Calcium S Pyr
# match value: 0.41, best match: L6 MO NPyr Slc17a7
#
#
# target name -> SSp L5-6 Pyr Thy1-YFP
# match value: 0.91, best match: R S , L5 Pyr of SS  YFP Thy1-YFP
# match value: 0.68, best match: Isocortex Pyr L5-6
# match value: 0.68, best match: SS L5-6 Pyr
# match value: 0.68, best match: Isocortex Pyr L5-6
# match value: 0.68, best match: Isocortex Pyr L5-6
# match value: 0.66, best match: ORB L5-6 Pyr
# match value: 0.66, best match: ORB L5-6 Pyr
# match value: 0.66, best match: medial ORB L5-6 Low-Threshold Calcium S Pyr
# match value: 0.66, best match: medial ORB L5-6 Non-Low-Threshold Calcium S Pyr
# match value: 0.65, best match: SSp L5 CThal projecting Pyr
# match value: 0.65, best match: SSp L5 CTrig projecting Pyr
# match value: 0.65, best match: SSp L5 CStr projecting Pyr
# match value: 0.65, best match: SSp L5 CCo projecting Pyr
# match value: 0.65, best match: SSp L5 Pyr
# match value: 0.62, best match: SS L5 apical Pyr
# match value: 0.62, best match: SS L5 apical Pyr
# match value: 0.62, best match: SSp-bfd CThal Pyr L6 with F AHP
# match value: 0.62, best match: SSp-bfd non- CThal Pyr L6 with medium AHP
# match value: 0.62, best match: Isocortex L5 Pyr
# match value: 0.62, best match: SS L5 Pyr
#
#
# target name -> ACA L5 TT Pyr Thy1-YFP
# match value: 0.83, best match: R S , L5 Pyr of SS  YFP Thy1-YFP
# match value: 0.71, best match: L5 VIS large TT Pyr
# match value: 0.71, best match: SS L5 TT Pyr
# match value: 0.63, best match: anterior ACA L5 Pyr
# ...
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name -> MO L5 TT Pyr Thy1-YFP
# match value: 0.83, best match: R S , L5 Pyr of SS  YFP Thy1-YFP
# match value: 0.71, best match: L5 VIS large TT Pyr
# match value: 0.71, best match: SS L5 TT Pyr
# match value: 0.65, best match: MOp L5b CSp TT large Pyr
# match value: 0.65, best match: MOp L5b CSp TT large Pyr
# match value: 0.65, best match: MOp L5b CSp TT large Pyr
# match value: 0.63, best match: L5 MO Pyr
# match value: 0.63, best match: SSs L5b CSp TT large Pyr
# match value: 0.61, best match: MOp L5 CThal Pyr
# match value: 0.61, best match: MOp L5 CSp Pyr
# match value: 0.61, best match: MOp L5 CCo Pyr
# match value: 0.61, best match: MOp L5 CStr Pyr
# match value: 0.61, best match: Isocortex L5 Pyr
# match value: 0.61, best match: Isocortex L5 large Pyr
# match value: 0.61, best match: L5 Isocortex Pyr
# match value: 0.61, best match: Isocortex L5 Pyr
# match value: 0.59, best match: ORB L5 large Pyr
# match value: 0.59, best match: VIS L5 R S tall Pyr
# match value: 0.59, best match: VIS L5 B tall Pyr
# match value: 0.59, best match: VIS L5 R S short Pyr
#
#
# target name -> MO F S basket G42
# match value: 0.69, best match: ORB L5 F S GFP-expressing G42 G42
# match value: 0.69, best match: AUD L2-3 F S G42 G42
# match value: 0.69, best match: AUD L2-3 F S G42 G42
# match value: 0.69, best match: AUD L2-3 F S G42 G42
# match value: 0.69, best match: SSp-bfd L4 F S G42 G42
# match value: 0.69, best match: VIS L5-6 F S G42 G42
# match value: 0.69, best match: VIS L5-6 F S G42 G42
# match value: 0.69, best match: VIS L5-6 F S G42 G42
# match value: 0.69, best match: VIS L5-6 F S G42 G42
# match value: 0.69, best match: L5 SS F S G42 G42
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
# match value: 0.51, best match: Isocortex basket
#
#
# target name -> LC Th NAdr
# match value: 0.71, best match: LC NAdr
# match value: 0.71, best match: LC NAdr
# match value: 0.71, best match: LC NAdr
# match value: 0.43, best match: LC neuropeptide S expressing
# match value: 0.43, best match: LC
# match value: 0.32, best match: BLA principal with input from ORB CTX
# match value: 0.32, best match: SOCm ventral
# match value: 0.32, best match: SOCm dorsal
# match value: 0.32, best match: SOCm ventral
# match value: 0.32, best match: SOCm dorsal
# match value: 0.32, best match: SUB Pyr projecting to RSP CTX
# match value: 0.32, best match: SUB Pyr projecting to lateral entorhinal cortex CTX
# match value: 0.32, best match: SUB Pyr projecting to medial entorhinal cortex CTX
# match value: 0.32, best match: SUB Pyr projecting to ORB CTX
# match value: 0.32, best match: L2-3 frontal Pyr projecting PERI CTX
# match value: 0.32, best match: L5 frontal Pyr projecting PERI CTX
# match value: 0.32, best match: medial entorihinal CTX L2 stellate
# match value: 0.32, best match: medial entorihinal CTX L2 stellate
# match value: 0.32, best match: jcBNST bed nucleus st type 2
# match value: 0.32, best match: jcBNST bed nucleus st type 3
#
#
# target name -> CB Pcp2 Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB VERM II-VIII lobules Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.71, best match: CB Purkinje
# match value: 0.66, best match: Densely Purkinje innerverted, FL targeting, gly
# match value: 0.43, best match: CB granule
# match value: 0.43, best match: CB Golgi
# match value: 0.43, best match: CB granule
#
#
# target name -> LC Th NAdr
# match value: 0.71, best match: LC NAdr
# match value: 0.71, best match: LC NAdr
# match value: 0.71, best match: LC NAdr
# match value: 0.43, best match: LC neuropeptide S expressing
# match value: 0.43, best match: LC
# match value: 0.32, best match: BLA principal with input from ORB CTX
# match value: 0.32, best match: SOCm ventral
# match value: 0.32, best match: SOCm dorsal
# match value: 0.32, best match: SOCm ventral
# match value: 0.32, best match: SOCm dorsal
# match value: 0.32, best match: SUB Pyr projecting to RSP CTX
# match value: 0.32, best match: SUB Pyr projecting to lateral entorhinal cortex CTX
# match value: 0.32, best match: SUB Pyr projecting to medial entorhinal cortex CTX
# match value: 0.32, best match: SUB Pyr projecting to ORB CTX
# match value: 0.32, best match: L2-3 frontal Pyr projecting PERI CTX
# match value: 0.32, best match: L5 frontal Pyr projecting PERI CTX
# match value: 0.32, best match: medial entorihinal CTX L2 stellate
# match value: 0.32, best match: medial entorihinal CTX L2 stellate
# match value: 0.32, best match: jcBNST bed nucleus st type 2
# match value: 0.32, best match: jcBNST bed nucleus st type 3
#
#
# target name -> SNc Th DA
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA Calb1
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA
# match value: 0.71, best match: SNc DA
# match value: 0.61, best match: VTA DA
# match value: 0.61, best match: VTA DA
# match value: 0.61, best match: VTA DA
# match value: 0.61, best match: VTA DA
# match value: 0.61, best match: VTA DA
# match value: 0.61, best match: VTA DA
# match value: 0.61, best match: VTA DA
# match value: 0.61, best match: VTA DA
# match value: 0.61, best match: VTA DA Calb1
#
#
# target name -> VTA Th DA
# match value: 0.71, best match: VTA DA
# match value: 0.71, best match: VTA DA
# match value: 0.71, best match: VTA DA
# match value: 0.71, best match: VTA DA
# match value: 0.71, best match: VTA DA
# match value: 0.71, best match: VTA DA
# match value: 0.71, best match: VTA DA
# match value: 0.71, best match: VTA DA
# match value: 0.71, best match: VTA DA Calb1
# match value: 0.71, best match: VTA DA
# match value: 0.61, best match: SNc DA
# match value: 0.61, best match: SNc DA
# match value: 0.61, best match: SNc DA
# match value: 0.61, best match: SNc DA
# match value: 0.61, best match: SNc DA
# match value: 0.61, best match: SNc DA
# match value: 0.61, best match: SNc DA Calb1
# match value: 0.61, best match: SNc DA
# match value: 0.61, best match: SNc DA
# match value: 0.61, best match: SNc DA
#
#
# target name -> Isocortex L2-3 Ntf3-expressing Pyr
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex L2-3 R S Non- Pyr
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex L2-3 R S Pyr
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 0.96, best match: L2-3 frontal Pyr projecting PERI CTX
# match value: 0.96, best match: SS L2-3 R S Pyr GIN GIN
# match value: 0.96, best match: SS L2-3 R S Pyr GIN GIN
# match value: 0.96, best match: SSp-bfd Pyr L2-3
# match value: 0.96, best match: SS L2-3 Pyr
# match value: 0.96, best match: L2-3 MO Pyr
# match value: 0.96, best match: ORB L2-3 Pyr
# match value: 0.96, best match: VIS L2-3 /V Pyr
# match value: 0.96, best match: VIS L2-3 /V Pyr
# match value: 0.96, best match: VIS L2-3 /V Pyr
#
#
# target name -> Isocortex L6 Ntsr1 Pyr
# match value: 0.81, best match: SSp-bfd CThal Pyr L6 with F AHP
# match value: 0.81, best match: SSp-bfd non- CThal Pyr L6 with medium AHP
# match value: 0.81, best match: L6 SS Pyr
# match value: 0.81, best match: L6 SS barrel column short Pyr
# match value: 0.81, best match: ORB L6 small Pyr
# match value: 0.81, best match: anterior ACA L6 Pyr
# match value: 0.73, best match: Isocortex Pyr L5-6
# match value: 0.73, best match: Isocortex Pyr L5-6
# match value: 0.73, best match: Isocortex Pyr L5-6
# match value: 0.70, best match: ORB L5-6 Pyr
# match value: 0.70, best match: SSp-bfd L6a CCo Pyr with infragranular arborization axons
# match value: 0.70, best match: L6a SSp-bfd Pyr CThal with large terminal arbors
# match value: 0.70, best match: SS L5-6 Pyr
# match value: 0.70, best match: ORB L5-6 Pyr
# match value: 0.70, best match: medial ORB L5-6 Low-Threshold Calcium S Pyr
# match value: 0.70, best match: medial ORB L5-6 Non-Low-Threshold Calcium S Pyr
# match value: 0.65, best match: L6 MO NPyr Slc17a7
# match value: 0.65, best match: SS L6 Mart
# match value: 0.65, best match: VISp L6 Antidromic Corticofugal Antidromic Corticofugal
# match value: 0.65, best match: VISp L6 Non-antidromic Corticofugal
#
#
# target name -> Isocortex NF F S Dlx1
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L2-3 LT S
# match value: 0.60, best match: Isocortex L5 Pyr
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L4 stellate
# match value: 0.60, best match: Isocortex L5 large Pyr
# match value: 0.60, best match: Isocortex basket
# match value: 0.60, best match: Isocortex Pyr L2-3
# match value: 0.60, best match: Isocortex Pyr L2-3
# match value: 0.60, best match: Isocortex Pyr L5-6
# match value: 0.60, best match: Isocortex L2-3 gaba L S subtype 1 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba L NF F S Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba L S subtype 2 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba B NAd Ad subtype 2 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba F Ad Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba B NAd Ad subtype 1 Htr3a
# match value: 0.60, best match: Isocortex L2-3 gaba I S bipolar Htr3a
#
#
# target name -> Isocortex F S Nek7-expressing
# match value: 1.00, best match: Isocortex basket
# match value: 1.00, best match: Isocortex L4 stellate
# match value: 1.00, best match: Isocortex L2-3 LT S
# match value: 1.00, best match: Isocortex L5 Pyr
# match value: 1.00, best match: Isocortex basket
# match value: 1.00, best match: Isocortex basket
# match value: 1.00, best match: Isocortex L4 stellate
# match value: 1.00, best match: Isocortex L4 stellate
# match value: 1.00, best match: Isocortex L5 large Pyr
# match value: 1.00, best match: Isocortex basket
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L2-3
# match value: 1.00, best match: Isocortex Pyr L5-6
# match value: 1.00, best match: Isocortex L2-3 gaba L S subtype 1 Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba L NF F S Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba L S subtype 2 Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba B NAd Ad subtype 2 Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba F Ad Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba B NAd Ad subtype 1 Htr3a
# match value: 1.00, best match: Isocortex L2-3 gaba I S bipolar Htr3a
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba
#
#
# target name ->
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: HIP glu N2D-EGFP- positive
# match value: 0.00, best match: CA3 Pyr
# match value: 0.00, best match: secondary motor cortex CSp Pyr
# match value: 0.00, best match: MOp CSp Pyr
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: glu HIP autaptic
# match value: 0.00, best match: MOB (main) mitral
# match value: 0.00, best match: BLA principal with input from ventral HIP
# match value: 0.00, best match: BLA principal with input from ORB CTX
# match value: 0.00, best match: ventral HIP stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated stimulated stimulated in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated F S in BLA sAMY
# match value: 0.00, best match: ORB stimulated stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ventral HIP stimulated NF F S in BLA sAMY
# match value: 0.00, best match: ORB infralimbic L2 ,III, and V Pyr
# match value: 0.00, best match: CP Sst /neuropeptide-Y/ Nos1 Nos2 negative negative Htr3a LT S gaba
# match value: 0.00, best match: CP neuropeptide-Y-negative Htr3a L S NG gaba

# %%
from similarity import similarity, similarity2
from similarity_intra import load_ontologies

# Computes the intra and inter semantic similarity between two neurons
# in: n1@str, n2@str: the two neurons to measure similarity
# out: (score:float, [(matching_properties, explanation@str)])
#similarity('PV Layer 1 cortex acetylcholine neuron', 'Layer 1a striatum gaba fast-spiking neuron')
print similarity('dorsal raphe serotonergic cell', 'Midbrain Slc6a4-expressing serotonergic cells', symmetric = True)
print similarity('Midbrain Slc6a4-expressing serotonergic cells', 'dorsal raphe serotonergic cell', symmetric = False)
# Out:
# (0.7708333333333334, [[], (['ABA_REGION:313'], 'sharing a common brain region'), [], [], [], ([u'HBP_NEUROTRANSMITTER:0000001'], 'shares neurotransmitters'), [], []])
# (0.6607142857142857, [[], (['ABA_REGION:313'], 'sharing a common brain region'), [], [], [], ([u'HBP_NEUROTRANSMITTER:0000001'], 'shares neurotransmitters'), [], []])

# %%
similarity2(gene_dict_list[25]['annotations'], dict_list[25]['annotations'])
# Out:
# (0.0, [[], [], [], [], [], [], [], []])

# %%
print dict_list[25]['short_name']
print gene_exp_table.iloc[51]['annotations']
# Out:
# SSs L5b CSp TT large Pyr
# [u'ABA_REGION:453', u'NCBI_GENE:19293', u'HBP_EPHYS:0000080', u'HBP_EPHYS_TRIGGER:0000003', u'HBP_MORPHOLOGY:0000019', 'Missing:from G42', 'Species:mouse', 'Missing:line', 'MOUSE_LINE:G42']

# %%
from  more_itertools import unique_everseen

def find_matching_neurons(target_neuron_anns, matching_ann_dict_list, match_thresh = .8):
    sim_vec = []
    sim_val_vec = []
    matching_neuron_list = []
    for d in matching_ann_dict_list:
        sim = similarity2(target_neuron_anns['annotations'], d['annotations'], symmetric = False, use_inter_similarity = False)
        sim_vec.append(sim)
        sim_val_vec.append(sim[0])
    sim_val_vec
    inds = sorted(range(len(sim_val_vec)),key=lambda x:sim_val_vec[x], reverse = True)
    for i in range(0, len(inds)):
        if sim_val_vec[inds[i]] > match_thresh:
            matching_neuron_list.append(dict_list[inds[i]]['neuron_name_orig'])
    if (len(matching_neuron_list) <= 2):
        #print match_thresh, target_neuron_anns
        return find_matching_neurons(target_neuron_anns, matching_ann_dict_list, match_thresh - .05)
    elif match_thresh < .4:
        return []
    return list(unique_everseen(matching_neuron_list))

# %%
ind = 63
#print gene_exp_table.iloc[ind]['neuron_name']
find_matching_neurons(gene_exp_table.iloc[ind], dict_list)
# Out:
# ['Layer 5 sensorimotor cortex pyramidal neurons',
#  'Primary motor cortex layer 5 corticothalamic pyramidal neuron',
#  'Primary motor cortex layer 5 corticospinal pyramidal neuron',
#  'Primary motor cortex layer 5 corticocortical pyramidal neuron',
#  'Primary motor cortex layer 5 corticostriatal pyramidal neuron',
#  'Neocortex Layer V Pyramidal Cell',
#  'neocortex layer 5 large pyramidal cell',
#  'Layer 5 neocortex pyramidal neuron',
#  'Neocortex layer 5 pyramidal neuron',
#  'Prefrontal cortex layer 5 large pyramidal neuron',
#  'visual cortex layer 5 regular spiking tall pyramidal neuron',
#  'visual cortex layer 5 bursting tall pyramidal neuron',
#  'visual cortex layer 5 regular spiking short pyramidal neuron',
#  'Layer 5 frontal pyramidal cells projecting perirhinal cortex  ',
#  'Regular spiking, Thy1-expressing layer V pyramidal neurons of somatosensory cortex ',
#  'Somatosensory cortex layer 5 apical pyramidal cell',
#  'prefrontal cortex layer 5 pyramidal neuron ',
#  'Layer 5 Visual Cortex large thick-tufted Pyramidal Neurons',
#  'Somatosensory cortex layer 5 pyramidal neurons',
#  'Layer 5 somatosensory cortex large amplitude pyramidal cells',
#  'Layer 5 somatosensory cortex small amplitude pyramidal cells ',
#  'medial prefrontal cortex layer 5 pyramidal cell',
#  'Layer 5 medial prefrontal cortex prelimbic pyramidal neurons',
#  'Layer 5 medial prefrontal cortex infralimbic pyramidal neurons',
#  'Layer 5 somatosensory barrel cortex pyramidal neurons',
#  'Prefrontal Cortex Layer 5 Pyramidal Neurons',
#  'somatosensory cortex layer V thick tufted pyramidal cell',
#  'somatosensory cortex layer V corticocallosal projecting pyramidal cell',
#  'Visual cortex layer 5 regular spiking pyramidal cell',
#  'Visual cortex layer 5 bursting pyramidal cell',
#  'Anterior Cingulate Cortex Layer V Pyramidal Neuron',
#  'primary somatosensory cortex layer 5 corticothalamic projecting pyramidal neurons',
#  'primary somatosensory cortex layer 5 corticotrigeminal projecting pyramidal neurons',
#  'primary somatosensory cortex layer 5 corticostriatal projecting pyramidal neurons ',
#  'primary somatosensory cortex layer 5 corticocallosal projecting pyramidal neurons',
#  'Somatosensory cortex layer 5 pyramidal cell',
#  'somatosensory cortex layer 5 pyramidal GABAergic neurons',
#  'primary somatosensory cortex layer 5 pyramidal neurons ',
#  'Medial Prefrontal Cortex Layer V Drd4-expressing Pyramidal Neuron',
#  'Medial Prefrontal Cortex Layer V non-Drd4-expressing Pyramidal Neuron',
#  'associative parietal and visual cortex layer 5 pyramidal cell projecting to superior colliculus',
#  'associative parietal and visual cortex layer 5 pyramidal cell projecting to contralateral cortex',
#  'Primary motor cortex layer 5b corticospinal thick-tufted large pyramidal neuron',
#  'Neocortex pyramidal cell layer 5-6']

# %%
import numpy as np
# use sherlok to annotate each curated neuron mention in neuroelectro
#annot_vec = []
gene_dict_list = []
for index, row in gene_exp_table.iterrows():
    temp_dict = {}
    if len(row['annotations']) > 0:
        matched_neuron_list = find_matching_neurons(row, dict_list)
    else:
        matched_neuron_list = []
    temp_dict['matched_neuron_list'] = ';'.join(matched_neuron_list)
    temp_dict['Index'] = index
    gene_dict_list.append(temp_dict)

# %%
df_gene = pd.DataFrame.from_records(gene_dict_list, index = 'Index')
gene_exp_table_final = gene_exp_table.join(df_gene)

# %%
gene_exp_table_final.head()
# Out:
#                                                    MajorType JustPyra  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...       NaN      NaN
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...       NaN      NaN
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839       NaN      NaN
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...    Neuron      NaN
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...    Neuron      NaN
#
#                                                        GabaDeep PyramidalDeep  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...          NaN           NaN
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...          NaN           NaN
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839          NaN           NaN
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...          NaN           NaN
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...  MotorCholin   MotorCholin
#
#                                                    Neurotransmitter1  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...               NaN
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...               NaN
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839               NaN
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...               NaN
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...      Cholinergic
#
#                                                      ShinyNames  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...          NaN
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...          NaN
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839          NaN
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...          NaN
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...  MotorCholin
#
#                                                     ShinySubtypes  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...            NaN
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...            NaN
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839            NaN
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...            NaN
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...            NaN
#
#                                                        CellType  forContanim  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...          NaN    Pyramidal
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...          NaN    Pyramidal
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839          NaN    Pyramidal
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...          NaN          NaN
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...  MotorCholin  MotorCholin
#
#                                                    Normalize2.0  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...            T
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...            T
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839            T
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...            F
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...            T
#
#                                                                           ...                          \
# Cell.Type..Samples                                                        ...
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...                        ...
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...                        ...
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839                        ...
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...                        ...
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...                        ...
#
#                                                                                           annotations  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...  [ABA_REGION:315, HBP_LAYER:0000050, NCBI_GENE:...
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...  [ABA_REGION:315, HBP_LAYER:0000051, NCBI_GENE:...
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839  [ABA_REGION:315, HBP_LAYER:0000006, NCBI_GENE:...
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...                  [ABA_REGION:315, NCBI_GENE:12424]
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...  [ABA_REGION:343, NCBI_GENE:12647, HBP_NEUROTRA...
#
#                                                    ephys      gene layer line  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...   NaN      Etv1   L5a  NaN
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...   NaN  Colgalt2   L5b  NaN
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839   NaN     Ntsr1    L6  NaN
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...   NaN       Cck   NaN  NaN
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...   NaN      Chat   NaN  NaN
#
#                                                                                           neuron_name  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...  Neocortex layer 5a Etv1-expressing slender-tuf...
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...  Neocortex layer 5b Glt25d2-expressing thick-tu...
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839  Neocortex layer 6 Ntsr1-expressing pyramidal c...
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...                      Neocortex Cck-expressing cell
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...  Brainstem Chat-expressing cholinergic motor ne...
#
#                                                        region   shape  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...  Isocortex  ST Pyr
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...  Isocortex  TT Pyr
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839  Isocortex     Pyr
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...  Isocortex     NaN
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...         BS     NaN
#
#                                                                        short_name  \
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...      Isocortex L5a Etv1 ST Pyr
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...  Isocortex L5b Colgalt2 TT Pyr
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839         Isocortex L6 Ntsr1 Pyr
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...                  Isocortex Cck
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...              BS Chat ACh motor
#
#                                                                                   matched_neuron_list
# Cell.Type..Samples
# H_lva_cortex:v2_GSM337817,v2_GSM337818,v2_GSM33...  barrel cortex pyramidal neurons layer 5a;Layer...
# H_lvb_cortex:v2_GSM337821,v2_GSM337822,v2_GSM33...  Secondary somatosensory cortex layer 5b cortic...
# H_l6_cortex:v2_GSM337837,v2_GSM337838,v2_GSM337839  barrel cortex corticothalamic pyramidal neuron...
# H_cck+_cortex:v2_GSM337769,v2_GSM337770,v2_GSM3...  frontal cortex Layer 2/3 non-pyramidal cholecy...
# H_mn_brainstem:v2_GSM337773,v2_GSM337774,v2_GSM...
#
# [5 rows x 39 columns]

# %%
# work on sorting gene exp rows by semantic similarity

from scipy.spatial.distance import squareform
from scipy.cluster.hierarchy import leaders, fclusterdata, linkage, dendrogram, leaves_list

# calculate pairwise distance matrix based on similarity
dist_mat = []
labels = []
for index, row1 in gene_exp_table_final.iterrows():
    sim_vec = []
    ann1 = row1['annotations']
    labels.append(row1['short_name'])
    for i, row2 in gene_exp_table.iterrows():
        ann2 = row2['annotations']
        
        (sim_val, exp) = similarity2(ann1, ann2, symmetric = True, use_inter_similarity = False)
        sim_dist = 1 - sim_val
        sim_vec.append(sim_dist)
    dist_mat.append(sim_vec)
    
# 
d = squareform(dist_mat)
Z = linkage(d)
sorted_rows = leaves_list(Z)

# %%
gene_exp_table_final = gene_exp_table_final.iloc[sorted_rows]
gene_exp_table_final.to_csv('df_gene.csv', sep='\t', encoding='utf-8')

# %%
dendrogram(Z, labels = labels)
# Out:
# array([ 82,  15,  16,  17,  18,  24,  25,  26,  27,  28,  29,  30,  31,
#         56,  57,  58,  59,  60,  61,  70,  72,  79,  80,  81,  83,  84,
#         85,  86,  87,  88,  89,  90,  91, 104, 105, 111, 119, 120, 121,
#        122,  50,  49,  55, 124,  51,  52,  53,  54, 106, 107, 108, 109,
#        110,  69,  92,  93,  94,  95,  96,  97,  98,  13,  11,  12,  14,
#         21,  22,  62,  19,  99, 100, 101, 126,  47,  48,  71,  42,  43,
#         44,  45,  46,   0, 102,  38, 118,  35,  36,  37, 115, 116, 117,
#         32,  33,  34,   1,  78,  40,  41,  67, 123,  63,  64,   3,   8,
#         20, 113,  23, 114,   2,  39,  10,  76,  77,   9,  73,  74,  75,
#        103, 128, 129,  65,  66,  68, 125, 127, 112,   4,   7,   5,   6], dtype=int32)
