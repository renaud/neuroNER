# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Comparing NeuroLex and BBP ontologies

# %%
from similarity import _cleanup, _normalize,   similarity2

from sherlok import Sherlok
neuroner = Sherlok('neuroner')

# %%
# PARSE OBO
import oboparser, re

hbp_obo_file = 'hbp_neurolex/hbp_cell_ontology.obo'
nlex_obo_file = 'hbp_neurolex/neurolex.obo'

# a simple function to pull out the cell names
SYNONOYM_NAME = re.compile(r'"(.*?)"').search
def get_cell_names(obo_onto_file):
    cell_names = {}    
    for stanza in oboparser.parse(obo_onto_file):
        if stanza['@type'] != "Term": continue
        id = stanza["id"]
        if id == '': continue
        name = stanza["name"]
        synonyms = []
        for s in stanza["synonym"]:
            synonyms.append(SYNONOYM_NAME(s).group(1))
        cell_names[id] = (name, synonyms)
    return cell_names

hbp_cell_names  = get_cell_names(hbp_obo_file)
nlex_cell_names = get_cell_names(nlex_obo_file)
print 'hbp_cell_names', len(hbp_cell_names)
print 'nlex_cell_names', len(nlex_cell_names)
assert hbp_cell_names['HBP_CELL:0000016'][0] == 'neuron expressing Parvalbumin'
assert hbp_cell_names['HBP_CELL:0000016'][1][1] == 'Pvalb+ cell'
# Out:
# hbp_cell_names 133
# nlex_cell_names 750

# %%
# PREPROCESS NEUROLEX and HBP
def preprocess(cell_names):
    cell_names_processed = {}
    for id, entity in cell_names.items():
        name, synonyms = entity
        print('name::', name, "id:", id)
        variants = []
        variants.append(_cleanup(neuroner.annotate(name).annotations)) # name
        for s in synonyms:
            print('         syn::',s)
            variants.append(_cleanup(neuroner.annotate(name).annotations)) # synonyms
        cell_names_processed[id] = variants
    return cell_names_processed

hbp_cell_names_processed  = preprocess(hbp_cell_names)
nlex_cell_names_processed = preprocess(nlex_cell_names)
print('done :-)')
# Out:
# ('name::', 'Axonal Cell', 'id:', 'HBP_CELL:0000065')
# ('name::', 'Nest Basket Cell', 'id:', 'HBP_CELL:0000064')
# ('         syn::', 'arcade cell')
# ('         syn::', 'willow cell')
# ('         syn::', 'NBC')
# ('name::', 'Large Axon Cell', 'id:', 'HBP_CELL:0000067')
# ('         syn::', 'LAC')
# ('name::', 'Descending Axon Cell', 'id:', 'HBP_CELL:0000066')
# ('         syn::', 'DAC')
# ('name::', 'Cajal-Retzius cell like cell', 'id:', 'HBP_CELL:0000061')
# ('         syn::', 'CrC')
# ('name::', 'Chandelier Cell', 'id:', 'HBP_CELL:0000060')
# ('         syn::', 'Axo-axonic cell')
# ('         syn::', 'ChC')
# ('name::', 'Large Basket Cell', 'id:', 'HBP_CELL:0000063')
# ('         syn::', 'LBC')
# ('name::', 'Small Basket Cell', 'id:', 'HBP_CELL:0000062')
# ('         syn::', 'SBC')
# ('name::', 'Layer V Neurogliaform Cell', 'id:', 'HBP_CELL:0000115')
# ('         syn::', 'L5_NGC')
# ('name::', 'Layer IV Neurogliaform Cell', 'id:', 'HBP_CELL:0000114')
# ('         syn::', 'L4_NGC')
# ('name::', 'Layer II/III Martinotti Cell', 'id:', 'HBP_CELL:0000117')
# ('         syn::', 'L23_MC')
# ('         syn::', 'L2/3_MC')
# ('name::', 'Layer VI Neurogliaform Cell', 'id:', 'HBP_CELL:0000116')
# ('         syn::', 'L6_NGC')
# ('name::', 'Small Axon Cell', 'id:', 'HBP_CELL:0000069')
# ('         syn::', 'SAC')
# ('         syn::', 'SLAC')
# ('name::', 'Horizontal Axon Cell', 'id:', 'HBP_CELL:0000068')
# ('         syn::', 'HAC')
# ('name::', 'Layer II/III Neurogliaform Cell', 'id:', 'HBP_CELL:0000113')
# ('         syn::', 'L23_NGC')
# ('         syn::', 'L2/3_NGC')
# ('name::', 'Layer VI Double Bouquet Cell', 'id:', 'HBP_CELL:0000112')
# ('         syn::', 'L6_DBC')
# ('name::', 'Layer V Martinotti Cell', 'id:', 'HBP_CELL:0000119')
# ('         syn::', 'L5_MC')
# ('name::', 'Layer IV Martinotti Cell', 'id:', 'HBP_CELL:0000118')
# ('         syn::', 'L4_MC')
# ('name::', 'Layer IV Bipolar Cell', 'id:', 'HBP_CELL:0000098')
# ('         syn::', 'L4_BP')
# ('name::', 'Layer V Bipolar Cell', 'id:', 'HBP_CELL:0000099')
# ('         syn::', 'L5_BP')
# ('name::', 'Layer I Neurogliaform Cell with Dense Axonal Arbour', 'id:', 'HBP_CELL:0000091')
# ('         syn::', 'L1_NGC-DA')
# ('name::', 'Layer I Neurogliaform Cell with Sparse Axon Arbour', 'id:', 'HBP_CELL:0000092')
# ('         syn::', 'L1_NGC-SA')
# ('name::', 'Layer I Descending Axon Cell', 'id:', 'HBP_CELL:0000093')
# ('         syn::', 'L1_DAC')
# ('name::', 'Layer I Horizontal Axon Cell', 'id:', 'HBP_CELL:0000094')
# ('         syn::', 'L1_HAC')
# ('name::', 'Layer I Large Axon Cell', 'id:', 'HBP_CELL:0000095')
# ('         syn::', 'L1_LAC')
# ('name::', 'Layer I Small Axon Cell', 'id:', 'HBP_CELL:0000096')
# ('         syn::', 'L1_SAC')
# ('name::', 'Layer II/III Bipolar Cell', 'id:', 'HBP_CELL:0000097')
# ('         syn::', 'L23_BP')
# ('         syn::', 'L2/3_BP')
# ('name::', 'neuron classified based on gene expression', 'id:', 'HBP_CELL:0000010')
# ('name::', 'neuron expressing Neuropeptide Y', 'id:', 'HBP_CELL:0000011')
# ('         syn::', 'NPY+ cell')
# ('name::', 'neuron expressing Vasoactive Intestinal Peptide', 'id:', 'HBP_CELL:0000012')
# ('         syn::', 'VIP+ cell')
# ('name::', 'neuron expressing Cholecystokinin', 'id:', 'HBP_CELL:0000013')
# ('         syn::', 'CCK+ cell')
# ('name::', 'neuron expressing Calbindin', 'id:', 'HBP_CELL:0000014')
# ('         syn::', 'calbindin 1 expressing cell')
# ('         syn::', 'CB+ cell')
# ('name::', 'neuron expressing Somatostatin', 'id:', 'HBP_CELL:0000015')
# ('         syn::', 'SOM+ cell')
# ('         syn::', 'Sst+ cell')
# ('name::', 'neuron expressing Parvalbumin', 'id:', 'HBP_CELL:0000016')
# ('         syn::', 'PV+ cell')
# ('         syn::', 'Pvalb+ cell')
# ('name::', 'neuron expressing Calretinin', 'id:', 'HBP_CELL:0000017')
# ('         syn::', 'Calb2+ cell')
# ('         syn::', 'CR+ cell')
# ('name::', 'pyramidal cell', 'id:', 'HBP_CELL:0000018')
# ('         syn::', 'PC')
# ('name::', 'Inhibitory neuron', 'id:', 'HBP_CELL:0000019')
# ('name::', 'Delayed Accomodating Cell', 'id:', 'HBP_CELL:0000089')
# ('         syn::', 'dAC')
# ('name::', 'Delayed Non-Accomodating Cell', 'id:', 'HBP_CELL:0000088')
# ('         syn::', 'dNAC')
# ('name::', 'Burst Stuttering Cell', 'id:', 'HBP_CELL:0000083')
# ('         syn::', 'bSTUT')
# ('name::', 'Classical Accomodating Cell', 'id:', 'HBP_CELL:0000082')
# ('         syn::', 'cAC')
# ('name::', 'Classical Non-Accomodating Cell', 'id:', 'HBP_CELL:0000081')
# ('         syn::', 'cNAC')
# ('name::', 'Classical Irregular Cell', 'id:', 'HBP_CELL:0000080')
# ('         syn::', 'cIR')
# ('name::', 'Delayed Stuttering Cell', 'id:', 'HBP_CELL:0000087')
# ('         syn::', 'dSTUT')
# ('name::', 'Burst Accomodating Cell', 'id:', 'HBP_CELL:0000086')
# ('         syn::', 'bAC')
# ('name::', 'Burst Irregular Cell', 'id:', 'HBP_CELL:0000085')
# ('         syn::', 'bIR')
# ('name::', 'Burst Non-Accomodating Cell', 'id:', 'HBP_CELL:0000084')
# ('         syn::', 'bNAC')
# ('name::', 'Layer II/III Double Bouquet Cell', 'id:', 'HBP_CELL:0000109')
# ('         syn::', 'L23_DBC')
# ('         syn::', 'L2/3_DBC')
# ('name::', 'neuron classified base morphological properties', 'id:', 'HBP_CELL:0000003')
# ('name::', 'glial cell', 'id:', 'HBP_CELL:0000002')
# ('name::', 'neuron', 'id:', 'HBP_CELL:0000001')
# ('name::', 'cell', 'id:', 'HBP_CELL:0000000')
# ('name::', 'neuron classified based on neurotransmitter release', 'id:', 'HBP_CELL:0000007')
# ('name::', 'neuron classified based on connection properties', 'id:', 'HBP_CELL:0000006')
# ('name::', 'neuron classified based on molecular expression', 'id:', 'HBP_CELL:0000005')
# ('name::', 'neuron classified base electrical properties', 'id:', 'HBP_CELL:0000004')
# ('name::', 'neuron classified based on protein expression', 'id:', 'HBP_CELL:0000009')
# ('name::', 'neuron classified based on synaptic properties', 'id:', 'HBP_CELL:0000008')
# ('name::', 'Layer VI Bipolar Cell', 'id:', 'HBP_CELL:0000100')
# ('         syn::', 'L6_BP')
# ('name::', 'Layer II/III Bitufted Cell', 'id:', 'HBP_CELL:0000101')
# ('         syn::', 'L23_BTC')
# ('         syn::', 'L2/3_BTC')
# ('name::', 'Tufted Pyramidal Cell towards Layer I', 'id:', 'HBP_CELL:0000036')
# ('         syn::', 'TPC_L1')
# ('name::', 'Thick Tufted Pyramidal Cell', 'id:', 'HBP_CELL:0000037')
# ('         syn::', 'TTPC')
# ('name::', 'neuron classified base on regional projection', 'id:', 'HBP_CELL:0000034')
# ('name::', 'Tufted Pyramidal Cell towards Layer IV', 'id:', 'HBP_CELL:0000035')
# ('         syn::', 'TPC_L4')
# ('name::', 'Narrow Pyramidal Cell projecting to thalamus', 'id:', 'HBP_CELL:0000032')
# ('         syn::', 'NPC')
# ('name::', 'neuron classified based on location', 'id:', 'HBP_CELL:0000033')
# ('name::', 'Horizontal Pyramidal Cell', 'id:', 'HBP_CELL:0000030')
# ('         syn::', 'HPC')
# ('name::', 'Bipolar Pyramidal Cell', 'id:', 'HBP_CELL:0000031')
# ('         syn::', 'BPC')
# ('name::', 'Slender Tufted Pyramidal Cell', 'id:', 'HBP_CELL:0000038')
# ('         syn::', 'STPC')
# ('name::', 'Early bifurcating Thick Tufted Pyramidal Cell', 'id:', 'HBP_CELL:0000039')
# ('         syn::', 'TTPC2')
# ('name::', 'Layer VI Pyramidal Cell', 'id:', 'HBP_CELL:0000029')
# ('         syn::', 'L4_PC')
# ('name::', 'Layer II/III Pyramidal Cell', 'id:', 'HBP_CELL:0000028')
# ('         syn::', 'L23_PC')
# ('         syn::', 'L2/3_PC')
# ('name::', 'Glutamatergic neuron', 'id:', 'HBP_CELL:0000021')
# ('name::', 'Excitatory neuron', 'id:', 'HBP_CELL:0000020')
# ('name::', 'tufted pyramidal cell', 'id:', 'HBP_CELL:0000023')
# ('         syn::', 'TPC')
# ('name::', 'GABAergic neuron', 'id:', 'HBP_CELL:0000022')
# ('name::', 'Spiny Stellate Cell', 'id:', 'HBP_CELL:0000025')
# ('         syn::', 'SS')
# ('         syn::', 'SSC')
# ('name::', 'Untufted Pyramidal Cell', 'id:', 'HBP_CELL:0000024')
# ('         syn::', 'UTPC')
# ('name::', 'Star Pyramidal Cell', 'id:', 'HBP_CELL:0000027')
# ('         syn::', 'SPC')
# ('         syn::', 'SP')
# ('name::', 'Layer 4 Spiny Stellate Cell', 'id:', 'HBP_CELL:0000026')
# ('         syn::', 'L4_SS')
# ('name::', 'Layer VI Large Basket Cell', 'id:', 'HBP_CELL:0000124')
# ('         syn::', 'L6_LBC')
# ('name::', 'Layer II/III Nest Basket Cell', 'id:', 'HBP_CELL:0000125')
# ('         syn::', 'L23_NBC')
# ('         syn::', 'L2/3_NBC')
# ('name::', 'Layer II/III Small Basket Cell', 'id:', 'HBP_CELL:0000126')
# ('         syn::', 'L23_SBC')
# ('         syn::', 'L2/3_SBC')
# ('name::', 'Layer IV Small Basket Cell', 'id:', 'HBP_CELL:0000127')
# ('         syn::', 'L4_SBC')
# ('name::', 'Layer VI Martinotti Cell', 'id:', 'HBP_CELL:0000120')
# ('         syn::', 'L6_MC')
# ('name::', 'Layer II/III Large Basket Cell', 'id:', 'HBP_CELL:0000121')
# ('         syn::', 'L23_LBC')
# ('         syn::', 'L2/3_LBC')
# ('name::', 'Layer IV Large Basket Cell', 'id:', 'HBP_CELL:0000122')
# ('         syn::', 'L4_LBC')
# ('name::', 'Layer V Large Basket Cell', 'id:', 'HBP_CELL:0000123')
# ('         syn::', 'L5_LBC')
# ('name::', 'Layer V Small Basket Cell', 'id:', 'HBP_CELL:0000128')
# ('         syn::', 'L5_SBC')
# ('name::', 'Layer VI Small Basket Cell', 'id:', 'HBP_CELL:0000129')
# ('         syn::', 'L6_SBC')
# ('name::', 'Neurogliaform Cell with Dense Axonal Arbours', 'id:', 'HBP_CELL:0000058')
# ('         syn::', 'NGC-DA')
# ('name::', 'Double Bouquet Cell', 'id:', 'HBP_CELL:0000059')
# ('         syn::', 'DBC')
# ('name::', 'Bitufted Cell', 'id:', 'HBP_CELL:0000054')
# ('         syn::', 'BTC')
# ('name::', 'Martinotti Cell', 'id:', 'HBP_CELL:0000055')
# ('         syn::', 'MC')
# ('name::', 'Neurogliaform Cell', 'id:', 'HBP_CELL:0000056')
# ('         syn::', 'NGC')
# ('name::', 'Neurogliaform Cell with Sparse Axonal Arbours', 'id:', 'HBP_CELL:0000057')
# ('         syn::', 'NGC-SA')
# ('name::', 'Layer V Slender Tufted Pyramidal Cell', 'id:', 'HBP_CELL:0000050')
# ('         syn::', 'L5_STPC')
# ('name::', 'Layer VI Tufted Pyramidal Cell towards Layer I', 'id:', 'HBP_CELL:0000051')
# ('         syn::', 'L6_TPC_L1')
# ('name::', 'Basket Cell', 'id:', 'HBP_CELL:0000052')
# ('         syn::', 'BC')
# ('name::', 'Bipolar Cell', 'id:', 'HBP_CELL:0000053')
# ('         syn::', 'BP')
# ('name::', 'GABAergic interneuron', 'id:', 'HBP_CELL:0000133')
# ('name::', 'Layer VI Nest Basket Cell', 'id:', 'HBP_CELL:0000132')
# ('         syn::', 'L6_NBC')
# ('name::', 'Layer V Nest Basket Cell', 'id:', 'HBP_CELL:0000131')
# ('         syn::', 'L5_NBC')
# ('name::', 'Layer IV Nest Basket Cell', 'id:', 'HBP_CELL:0000130')
# ('         syn::', 'L4_NBC')
# ('name::', 'Layer VI Chandelier Cell', 'id:', 'HBP_CELL:0000108')
# ('         syn::', 'L6_ChC')
# ('name::', 'Layer V Double Bouquet Cell', 'id:', 'HBP_CELL:0000111')
# ('         syn::', 'L5_DBC')
# ('name::', 'Layer V Untufted Pyramidal Cell', 'id:', 'HBP_CELL:0000049')
# ('         syn::', 'L5_UTPC')
# ('name::', 'Layer V Early bifurcating Thick Tufted Pyramidal Cell', 'id:', 'HBP_CELL:0000048')
# ('         syn::', 'L5_TTPC2')
# ('name::', 'Layer VI Bipolar Pyramidal Cell', 'id:', 'HBP_CELL:0000047')
# ('         syn::', 'L6_BPC')
# ('name::', 'Layer VI Inverted Pyramidal Cell', 'id:', 'HBP_CELL:0000046')
# ('         syn::', 'L6_IPC')
# ('name::', 'Layer VI Untufted Pyramidal Cell', 'id:', 'HBP_CELL:0000045')
# ('         syn::', 'L6_UTPC')
# ('name::', 'Layer V Late bifurcating Thick Tufted Pyramidal Cell', 'id:', 'HBP_CELL:0000044')
# ('         syn::', 'L5_TTPC1')
# ('name::', 'Layer VI Tufted Pyramidal Cell towards Layer IV', 'id:', 'HBP_CELL:0000043')
# ('         syn::', 'L6_TTPC_L4')
# ('name::', 'Inverted Pyramidal Cell', 'id:', 'HBP_CELL:0000042')
# ('         syn::', 'ITPC')
# ('         syn::', 'IPC')
# ('name::', 'Untufted Slender Pyramidal Cell', 'id:', 'HBP_CELL:0000041')
# ('         syn::', 'USPC')
# ('name::', 'Late bifurcating Thick Tufted Pyramidal Cell', 'id:', 'HBP_CELL:0000040')
# ('         syn::', 'TTPC1')
# ('name::', 'Stuttering Cell', 'id:', 'HBP_CELL:0000072')
# ('         syn::', 'STUT')
# ('name::', 'Non-Accomodating Cell', 'id:', 'HBP_CELL:0000073')
# ('         syn::', 'NAC')
# ('name::', 'neuron classified based on firing behavior', 'id:', 'HBP_CELL:0000070')
# ('name::', 'neuron classified based on spike behavior', 'id:', 'HBP_CELL:0000071')
# ('name::', 'Classical Firing Cell', 'id:', 'HBP_CELL:0000076')
# ('name::', 'Burst Firing Cell', 'id:', 'HBP_CELL:0000077')
# ('name::', 'Accomodating Cell', 'id:', 'HBP_CELL:0000074')
# ('         syn::', 'AC')
# ('name::', 'Irregular Spiking Cell', 'id:', 'HBP_CELL:0000075')
# ('         syn::', 'IR')
# ('name::', 'Layer IV Bitufted Cell', 'id:', 'HBP_CELL:0000102')
# ('         syn::', 'L4_BTC')
# ('name::', 'Layer V Bitufted Cell', 'id:', 'HBP_CELL:0000103')
# ('         syn::', 'L5_BTC')
# ('name::', 'Delayed Firing Cell', 'id:', 'HBP_CELL:0000078')
# ('name::', 'Classical Stuttering Cell', 'id:', 'HBP_CELL:0000079')
# ('         syn::', 'cSTUT')
# ('name::', 'Layer IV Chandelier Cell', 'id:', 'HBP_CELL:0000106')
# ('         syn::', 'L4_ChC')
# ('name::', 'Layer V Chandelier Cell', 'id:', 'HBP_CELL:0000107')
# ('         syn::', 'L5_ChC')
# ('name::', 'Layer VI Bitufted Cell', 'id:', 'HBP_CELL:0000104')
# ('         syn::', 'L6_BTC')
# ('name::', 'Layer II/III Chandelier Cell', 'id:', 'HBP_CELL:0000105')
# ('         syn::', 'L23_ChC')
# ('         syn::', 'L2/3_ChC')
# ('name::', 'Layer IV Double Bouquet Cell', 'id:', 'HBP_CELL:0000110')
# ('         syn::', 'L4_DBC')
# ('name::', 'Anteriolateral neurosecretory cell', 'id:', 'nlx_147720')
# ('name::', 'Dorsomedial neurosecretory cell', 'id:', 'nlx_147721')
# ('name::', 'Posteriolateral neurosecretory cell', 'id:', 'nlx_147722')
# ('name::', 'Spinal cord ventral horn interneuron V0C', 'id:', 'nlx_cell_1006021')
# ('         syn::', 'V0c interneuron')
# ('         syn::', 'spinal cord V0c interneuron')
# ('name::', 'Hypoglossal nucleus motor neuron', 'id:', 'nlx_cell_100311')
# ('         syn::', 'hypoglossal motor neuron')
# ('         syn::', 'hypoglossal nucleus motoneuron')
# ('         syn::', 'hypoglossal motoneuron')
# ('         syn::', '12th nerve motor neuron')
# ('         syn::', 'XII nerve motor neuron')
# ('name::', 'Pb-fb-fb neuron', 'id:', 'nlx_147378')
# ('name::', 'Hippocampus CA1 IS-II neuron', 'id:', 'nlx_cell_1006029')
# ('         syn::', 'CA1 IS-II cell')
# ('name::', 'Tyraminergic neuron', 'id:', 'nlx_148704')
# ('name::', 'Retina starburst amacrine cell', 'id:', 'nifext_37')
# ('         syn::', 'Starburst amacrine cell')
# ('         syn::', 'Retina amacrine cell starburst')
# ('name::', 'Retina type 6 cone bipolar cell', 'id:', 'BAMSC1020')
# ('         syn::', 'type 6 cone bipolar cell')
# ('name::', 'Retina type 7 cone bipolar cell', 'id:', 'BAMSC1021')
# ('         syn::', 'type 7 cone bipolar cell')
# ('name::', 'Aplysia cerebral ganglion metacerebral cell', 'id:', 'nlx_cell_20090313')
# ('         syn::', 'Giant Serotonergic Neuron')
# ('         syn::', 'Metacerebral cell')
# ('name::', 'U5sib neuron', 'id:', 'nlx_147928')
# ('name::', 'Hippocampus CA2 pyramidal neuron', 'id:', 'nlx_cell_20090311')
# ('         syn::', 'CA2 pyramidal cell')
# ('name::', 'U4sib neuron', 'id:', 'nlx_147926')
# ('name::', 'U5 neuron', 'id:', 'nlx_147927')
# ('name::', 'EH neurosecretory neuron', 'id:', 'nlx_147924')
# ('         syn::', 'EH neuron')
# ('name::', 'Abdominal intersegmental bidendritic neuron isbp', 'id:', 'nlx_146896')
# ('         syn::', 'abdominal intersegmental bidendritic neuron isbd')
# ('name::', 'Retina thin dendrite horizontal cell', 'id:', 'nlx_152142')
# ('name::', 'Retina Retina narrow-field AII amacrine cell', 'id:', 'nlx_152143')
# ('name::', 'Bipolar dendrite neuron', 'id:', 'nlx_147850')
# ('name::', 'Dendritic arborizing neuron', 'id:', 'nlx_147851')
# ('         syn::', 'da neuron')
# ('name::', 'Neocortex primary visual layer 5 callosal cell', 'id:', 'nlx_143940')
# ('name::', 'Hypothalamus oxytocin neuroendocrine magnocellular cell', 'id:', 'nlx_416')
# ('name::', 'Ventral midline neuron', 'id:', 'nlx_147858')
# ('name::', 'DesD neuron', 'id:', 'nlx_146722')
# ('name::', 'Neocortex primary motor area pyramidal layer 5 callosal cell', 'id:', 'nlx_152138')
# ('name::', 'Thalamus geniculate nucleus (medial) principal neuron', 'id:', 'nlx_cell_1005001')
# ('name::', 'Dorsal tegmental nucleus small cell', 'id:', 'nlx_cell_20090402')
# ('         syn::', 'Dorsal tegmental nucleus small neuron')
# ('name::', 'Dorsal tegmental nucleus medium cell', 'id:', 'nlx_cell_20090403')
# ('         syn::', 'Dorsal tegmental nucleus medium neuron')
# ('name::', 'Neocortex pyramidal layer 2-3 cell', 'id:', 'nifext_49')
# ('         syn::', 'corticocortical cell')
# ('         syn::', 'superficial pyramidal cell')
# ('         syn::', 'Neocortex pyramidal neuron layer 2-3')
# ('         syn::', 'Layer 2-3 pyramidal cell')
# ('         syn::', 'Neocortical pyramidal neuron: superficial')
# ('         syn::', 'deep layer (layer 5')
# ('         syn::', '6) pyramidal cell')
# ('name::', 'Solitary tract nucleus HSD2 neuron', 'id:', 'BAMSC1112')
# ('         syn::', 'HSD2 neuron')
# ('         syn::', 'HSD2 cell')
# ('name::', 'Mechanosensory neuron of adult labial sensillum 5', 'id:', 'nlx_148459')
# ('name::', 'Bilateral intrinsic neuron', 'id:', 'nlx_147700')
# ('name::', 'Spinocerebellar tract cell', 'id:', 'nifext_102')
# ('         syn::', 'Dorsal spinocerebellar tract cell')
# ('name::', 'Solitary tract nucleus principal cell', 'id:', 'nifext_100')
# ('name::', 'Solitary tract nucleus intrinsic cell', 'id:', 'nifext_101')
# ('         syn::', 'Nucleus of the solitary tract')
# ('name::', 'Spinal cord ventral horn motor neuron beta', 'id:', 'nifext_106')
# ('         syn::', 'Beta motor neuron')
# ('name::', 'Retina horizontal cell', 'id:', 'nifext_40')
# ('         syn::', 'horizontal cell (retina)')
# ('name::', 'Amacrine neuron', 'id:', 'nlx_158403')
# ('         syn::', 'amacrine cell')
# ('name::', 'Neocortex dorsolateral prefrontal area layer 5 calbindin cell', 'id:', 'nlx_156753')
# ('         syn::', 'Neocortical interneurons')
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Neocortex Dorsolateral prefrontal area layer 4 Calbindin cell', 'id:', 'nlx_156750')
# ('         syn::', 'Neocortical interneurons')
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Neocortex dorsolateral prefrontal area layer 6 calbindin cell', 'id:', 'nlx_156754')
# ('         syn::', 'Neocortical interneurons')
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Vestibular type 1 hair cell', 'id:', 'sao709770772')
# ('         syn::', 'Vestibular hair cell')
# ('name::', 'Trigeminal nucleus motor neuron', 'id:', 'nlx_44081')
# ('         syn::', 'trigeminal nucleus motor cell')
# ('         syn::', '5th nerve motor neuron')
# ('         syn::', 'Vth nerve motor neuron')
# ('name::', 'Thalamus ventroposterior nucleus interneuron', 'id:', 'nlx_151692')
# ('name::', 'Thalamus ventroposterior nucleus principal neuron', 'id:', 'nlx_151691')
# ('name::', 'Thalamus geniculate nucleus (medial) interneuron', 'id:', 'nlx_151690')
# ('name::', 'Metathoracic anterior fascicle neuron', 'id:', 'nlx_146858')
# ('name::', 'Ventral tegmental area dopamine neuron', 'id:', 'nlx_cell_20090305')
# ('         syn::', 'Ventral tegmental area DA cell')
# ('         syn::', 'ventral tegmental area dopaminergic neuron')
# ('         syn::', 'VTA dopaminergic neuron')
# ('name::', 'Mechanosensory neuron of adult labial sensillum 3', 'id:', 'nlx_148457')
# ('name::', 'Mechanosensory neuron of adult labial sensillum 2', 'id:', 'nlx_148456')
# ('name::', 'Mechanosensory neuron of adult labial sensillum 1', 'id:', 'nlx_148455')
# ('name::', 'Carbon dioxide sensitive neuron', 'id:', 'nlx_148454')
# ('         syn::', 'CO2 sensitive neuron')
# ('name::', 'L2 GRN', 'id:', 'nlx_148453')
# ('name::', 'L1 GRN', 'id:', 'nlx_148452')
# ('name::', 'Larval Pdf neuron close to calyx', 'id:', 'nlx_148518')
# ('name::', 'S cell', 'id:', 'nlx_148450')
# ('name::', 'Larval Pdf neuron', 'id:', 'nlx_148516')
# ('name::', 'Larval pacemaker neuron', 'id:', 'nlx_148514')
# ('name::', 'Pupal pacemaker neuron', 'id:', 'nlx_148515')
# ('name::', 'Ventral cibarial sense organ neuron of distal sensillum', 'id:', 'nlx_148512')
# ('name::', 'Adult pacemaker neuron', 'id:', 'nlx_148513')
# ('name::', 'Gustatory receptor neuron of the hypopharyngeal sense organ', 'id:', 'nlx_148510')
# ('name::', 'Mechanosensory neuron of adult labial sensillum 4', 'id:', 'nlx_148458')
# ('name::', 'DRG II cell', 'id:', 'nifext_93')
# ('         syn::', 'II ganglion cell')
# ('name::', 'Hippocampus CA1 trilaminar neuron', 'id:', 'nlx_27085')
# ('         syn::', 'CA1 trilaminar cell')
# ('name::', 'Retina ganglion cell B2', 'id:', 'BAMSC1048')
# ('         syn::', 'retinal ganglion cell B2')
# ('name::', 'Tuberomammillary nucleus large histamine neuron', 'id:', 'nlx_78845')
# ('         syn::', 'Tubermammillary histaminergic neuron')
# ('name::', "V''esA neuron", 'id:', 'nlx_146770')
# ('name::', "V''esB neuron", 'id:', 'nlx_146771')
# ('name::', 'Ventral multidendritic neuron', 'id:', 'nlx_146772')
# ('name::', 'Sensory neuron of trichoid sensillum', 'id:', 'nlx_148060')
# ('name::', 'Hippocampus CA1 IS-III neuron', 'id:', 'nlx_36222')
# ('         syn::', 'CA1 IS-III cell')
# ('name::', 'Spinal cord proprioception intersegmental cell', 'id:', 'nifext_115')
# ('name::', 'Olfactory tubercle Islets of Calleja granule neuron', 'id:', 'nlx_68936')
# ('         syn::', 'Island of Calleja granule neuron')
# ('         syn::', 'Island of Calleja granule cell')
# ('name::', 'Retina photoreceptor S cone cell', 'id:', 'nlx_cell_100211')
# ('         syn::', 'Retina photoreceptor cone S')
# ('name::', 'Retina photoreceptor L cone cell', 'id:', 'nlx_cell_100210')
# ('         syn::', 'Retina photoreceptor cone L')
# ('name::', 'Retina photoreceptor rod cell', 'id:', 'nlx_cell_100212')
# ('         syn::', 'rod cell')
# ('         syn::', 'rod')
# ('         syn::', 'retinal rod photoreceptor')
# ('name::', 'Pb-eb-eb neuron', 'id:', 'nlx_147379')
# ('name::', 'Gravity sensitive Johnston organ neuron', 'id:', 'nlx_148422')
# ('         syn::', "gravity sensitive Johnston''s organ neuron")
# ('name::', 'Wind sensitive Johnston organ neuron', 'id:', 'nlx_148423')
# ('         syn::', "wind sensitive Johnston''s organ neuron")
# ('name::', 'Olfactory bulb (main) adult-born granule cell', 'id:', 'nlx_144252')
# ('name::', 'Zone A Johnston organ neuron', 'id:', 'nlx_148427')
# ('         syn::', 'zone A JON')
# ('name::', 'PreBotzinger complex neuron', 'id:', 'nlx_151905')
# ('name::', 'Mesothoracic anterior fascicle neuron', 'id:', 'nlx_146820')
# ('name::', 'Lamprey motor neuron', 'id:', 'nlx_151909')
# ('name::', 'Mauthner cell', 'id:', 'nlx_151908')
# ('         syn::', 'M-cell')
# ('name::', 'Oculomotor nucleus motor neuron', 'id:', 'nlx_77027')
# ('         syn::', 'oculomotor nucleus motor cell')
# ('         syn::', '3rd nerve motor neuron')
# ('         syn::', 'IIIrd nerve motor neuron')
# ('name::', 'Cochlea outer hair cell', 'id:', 'sao1582628662')
# ('         syn::', 'Cochlear Outer Hair Cell')
# ('         syn::', 'Outer Hair Cell')
# ('name::', 'Mushroom body ventral lobe arborizing neuron 1', 'id:', 'nlx_148584')
# ('         syn::', 'MB-V1')
# ('name::', 'Mushroom body ventral lobe arborizing neuron 4', 'id:', 'nlx_148587')
# ('         syn::', 'MB-V4')
# ('name::', 'Colliculus superior pyramidal cell', 'id:', 'BAMSC1123')
# ('         syn::', 'pyramidal cell')
# ('name::', 'Mushroom body medial lobe arborizing neuron 5', 'id:', 'nlx_148581')
# ('         syn::', 'MB-M5')
# ('name::', 'Mushroom body medial lobe arborizing neuron 4', 'id:', 'nlx_148580')
# ('         syn::', 'MB-M4')
# ('name::', 'Mushroom body medial lobe arborizing neuron 7', 'id:', 'nlx_148583')
# ('         syn::', 'MB-M7')
# ('name::', 'Mushroom body medial lobe arborizing neuron 6', 'id:', 'nlx_148582')
# ('         syn::', 'MB-M6')
# ('name::', 'Retina photoreceptor cone cell', 'id:', 'sao1103104164')
# ('         syn::', 'Cone cell')
# ('         syn::', 'cone')
# ('         syn::', 'retinal cone')
# ('name::', 'Mushroom body medial-vertical lobe arborizing neuron 1', 'id:', 'nlx_148589')
# ('         syn::', 'MB-MV1')
# ('name::', 'Mushroom body calyx-pedunculus arborizing neuron 1', 'id:', 'nlx_148588')
# ('         syn::', 'MB-C1')
# ('name::', 'Spinal cord intermediate horn motor neuron sympathetic', 'id:', 'nifext_109')
# ('         syn::', 'Sympathetic motor neuron')
# ('         syn::', 'preganglionic sympathetic neuron')
# ('name::', 'Substantia nigra pars reticulata interneuron GABA', 'id:', 'nifext_147')
# ('         syn::', 'substantia nigra pars reticulata GABA interneuron')
# ('         syn::', 'Substantia nigra pars reticulata GABA neuron')
# ('         syn::', 'Pars reticulata Gaba interneuron')
# ('name::', 'Ventral group vA neuron', 'id:', 'nlx_147803')
# ('         syn::', 'VA neuron')
# ('name::', 'Bed nucleus of the stria terminalis small pyramidal neuron', 'id:', 'BAMSC987')
# ('         syn::', 'small pyramidal neuron')
# ('         syn::', 'small pyramidal cell')
# ('         syn::', 'BNST small pyramidal neuron)')
# ('name::', 'Bed nucleus of the stria terminalis spiny bipolar neuron', 'id:', 'BAMSC986')
# ('         syn::', 'spiny bipolar neuron')
# ('         syn::', 'spiny bipolar cell')
# ('name::', 'III1 motor neuron', 'id:', 'nlx_147779')
# ('name::', 'B2 motor neuron', 'id:', 'nlx_147778')
# ('name::', 'Cerebellum candelabrum cell', 'id:', 'BAMSC981')
# ('         syn::', 'candelabrum cell')
# ('         syn::', 'candelabrum neuron')
# ('name::', 'Trigeminal nucleus intrinsic cell', 'id:', 'nifext_97')
# ('         syn::', 'Trigeminal nucleus intrinsic neuron')
# ('name::', 'III3 motor neuron', 'id:', 'nlx_147777')
# ('name::', 'B1 motor neuron', 'id:', 'nlx_147776')
# ('name::', 'Direct flight muscle motor neuron', 'id:', 'nlx_147775')
# ('name::', 'Bed nucleus of the stria terminalis basket neuron', 'id:', 'BAMSC988')
# ('         syn::', 'bed nucleus of stria terminalis basket cell')
# ('         syn::', 'bed nucleus of stria terminalis basket neuron')
# ('         syn::', 'Bed nucleus of the stria terminalis basket neuron')
# ('         syn::', 'BNST basket neuron')
# ('name::', 'Spinal cord ventral horn interneuron V2a', 'id:', 'nlx_144179')
# ('         syn::', 'V2a neuron')
# ('         syn::', 'V2a interneuron')
# ('name::', 'Nucleus laminaris principal neuron', 'id:', 'nlx_151646')
# ('         syn::', 'Analogous to the Medial Superior Olive (MSO) in mammals')
# ('name::', 'Glutamatergic neuron (FBbt Term)', 'id:', 'nlx_148635')
# ('name::', 'Larval olfactory receptor neuron Or45b', 'id:', 'nlx_148736')
# ('         syn::', 'ORN (Or45b)')
# ('name::', 'Larval olfactory receptor neuron Or49a', 'id:', 'nlx_148737')
# ('         syn::', 'ORN (Or49a)')
# ('name::', 'Larval olfactory receptor neuron Or42b', 'id:', 'nlx_148734')
# ('         syn::', 'ORN (Or42b)')
# ('name::', 'Larval olfactory receptor neuron Or45a', 'id:', 'nlx_148735')
# ('         syn::', 'ORN (Or45a)')
# ('name::', 'Larval olfactory receptor neuron Or35a', 'id:', 'nlx_148732')
# ('         syn::', 'ORN (Or35a)')
# ('name::', 'Larval olfactory receptor neuron Or42a', 'id:', 'nlx_148733')
# ('         syn::', 'ORN (Or42a)')
# ('name::', 'Larval olfactory receptor neuron Or33a', 'id:', 'nlx_148730')
# ('         syn::', 'ORN (Or33a)')
# ('name::', 'Larval olfactory receptor neuron Or33b / Or47a', 'id:', 'nlx_148731')
# ('         syn::', 'ORN (Or33b)')
# ('name::', 'Thalamus geniculate nucleus (lateral) interneuron', 'id:', 'nifext_46')
# ('         syn::', 'Small interneuron thalamic')
# ('         syn::', 'small thalamic interneuron')
# ('name::', 'Colliculus superior piriform cell', 'id:', 'BAMSC1117')
# ('         syn::', 'piriform cell')
# ('         syn::', 'piriform neuron')
# ('name::', 'Thalamus reticular nucleus cell', 'id:', 'nifext_45')
# ('         syn::', 'thalamic reticular cell')
# ('         syn::', 'Thalamic reticular nucleus neuron')
# ('         syn::', 'Thalamic reticular neuron')
# ('name::', 'Retina ganglion cell B3', 'id:', 'BAMSC1049')
# ('         syn::', 'retinal ganglion cell B3')
# ('name::', 'Larval olfactory receptor neuron Or59a', 'id:', 'nlx_148738')
# ('         syn::', 'ORN (Or59a)')
# ('name::', 'Larval olfactory receptor neuron Or63a', 'id:', 'nlx_148739')
# ('         syn::', 'ORN (Or63a)')
# ('name::', 'Retina stratified diffuse amacrine cell', 'id:', 'BAMSC1056')
# ('         syn::', 'stratified diffuse amacrine cell')
# ('name::', 'Retina bistratified amacrine cell', 'id:', 'BAMSC1055')
# ('         syn::', 'bistratified amacrine cell')
# ('name::', 'Retina ganglion cell C others', 'id:', 'BAMSC1051')
# ('         syn::', 'retinal ganglion cell C others')
# ('name::', 'Retina ganglion cell C1', 'id:', 'BAMSC1050')
# ('         syn::', 'retinal ganglion cell C1')
# ('name::', 'Cochlear nucleus (dorsal) cartwheel cell', 'id:', 'nifext_76')
# ('         syn::', 'Cartwheel neuron')
# ('name::', 'Midline neuron', 'id:', 'nlx_148280')
# ('name::', 'Cochlea inner hair cell', 'id:', 'sao429277527')
# ('         syn::', 'Cochlear Inner Hair Cell')
# ('         syn::', 'Inner Hair Cell')
# ('         syn::', 'Cochlea hair cell inner')
# ('name::', 'Aplysia buccal 8', 'id:', 'nlx_152509')
# ('name::', 'Substantia nigra pars reticulata principal cell', 'id:', 'nifext_148')
# ('         syn::', 'Substantia nigra pars reticulata principal neuron')
# ('name::', 'Globus pallidus principal cell', 'id:', 'nifext_149')
# ('name::', 'Peptidergic neuron', 'id:', 'nlx_147801')
# ('name::', 'Pdf neuron of abdominal neuromere', 'id:', 'nlx_147800')
# ('name::', 'Neostriatum SOM/NOS cell', 'id:', 'nifext_144')
# ('         syn::', 'striatal SOM/NOS interneuron')
# ('         syn::', 'SOM/NOS interneuron')
# ('         syn::', 'neostriatum SOM/NOS interneuron')
# ('         syn::', 'LTS cell')
# ('         syn::', 'PLTS cell')
# ('         syn::', 'somatostatin/nitric oxide synthase interneuron')
# ('name::', 'Dorsal group dA neuron', 'id:', 'nlx_147802')
# ('name::', 'Neostriatum gaba/parvalbumin interneuron', 'id:', 'nifext_143')
# ('         syn::', 'GABA/parvalbumin striatal interneuron')
# ('         syn::', 'fast-spiking interneuron')
# ('         syn::', 'FS Cell')
# ('name::', 'Trochlear nucleus motor neuron', 'id:', 'nlx_70345')
# ('         syn::', 'trochlear nucleus motor cell')
# ('         syn::', '4th nerve motor neuron')
# ('         syn::', 'IVth nerve motor neuron')
# ('name::', 'U neuron', 'id:', 'nlx_146556')
# ('         syn::', 'U / CQ neuron')
# ('name::', 'U1 neuron', 'id:', 'nlx_146557')
# ('name::', 'Spinal cord ventral horn motor neuron gamma', 'id:', 'sao1438006234')
# ('         syn::', 'fusimotor neuron')
# ('         syn::', 'Gamma motor neuron')
# ('name::', 'Tracheal innervating neuron', 'id:', 'nlx_147852')
# ('name::', 'U2 neuron', 'id:', 'nlx_146558')
# ('name::', 'U3 neuron', 'id:', 'nlx_146559')
# ('name::', 'Facial nucleus motor neuron', 'id:', 'nlx_50129')
# ('         syn::', 'facial nucleus motor cell')
# ('         syn::', '7th nerve motor neuron')
# ('         syn::', 'VIIth nerve motor neuron')
# ('name::', 'Indirect flight muscle motor neuron MN2', 'id:', 'nlx_147786')
# ('name::', 'Indirect flight muscle motor neuron MN3', 'id:', 'nlx_147787')
# ('name::', 'Indirect flight muscle motor neuron', 'id:', 'nlx_147784')
# ('name::', 'Indirect flight muscle motor neuron MN1', 'id:', 'nlx_147785')
# ('name::', 'Ventral tp motor neuron', 'id:', 'nlx_147782')
# ('name::', 'Endocrine neuron', 'id:', 'nlx_148126')
# ('name::', 'I1 motor neuron', 'id:', 'nlx_147780')
# ('name::', 'Dorsal tp motor neuron', 'id:', 'nlx_147781')
# ('name::', 'Retina thick dendrite horizontal cell', 'id:', 'nlx_152141')
# ('         syn::', 'H cell')
# ('name::', 'Indirect flight muscle motor neuron MN4', 'id:', 'nlx_147788')
# ('name::', 'Indirect flight muscle motor neuron MN5', 'id:', 'nlx_147789')
# ('name::', 'Ventral brain cluster neuron', 'id:', 'nlx_147894')
# ('name::', 'Dentate gyrus mossy cell', 'id:', 'nlx_22799')
# ('         syn::', 'Mossy cell')
# ('         syn::', 'Mossy neuron')
# ('         syn::', 'Dentate gyrus mossy neuron')
# ('name::', 'Lch3 neuron', 'id:', 'nlx_146738')
# ('name::', 'LP neuron', 'id:', 'nlx_148123')
# ('name::', 'DN3a neuron', 'id:', 'nlx_148122')
# ('name::', 'Dch3 neuron', 'id:', 'nlx_146730')
# ('name::', 'Dch3 / 1 neuron', 'id:', 'nlx_146731')
# ('name::', 'LesA neuron', 'id:', 'nlx_146732')
# ('name::', 'LesB neuron', 'id:', 'nlx_146733')
# ('name::', 'LesC neuron', 'id:', 'nlx_146734')
# ('name::', 'DN1p neuron', 'id:', 'nlx_148121')
# ('         syn::', 'DN1p')
# ('name::', 'Les4 neuron', 'id:', 'nlx_146737')
# ('name::', 'Fan-shaped neuron', 'id:', 'nlx_147391')
# ('         syn::', 'F neuron')
# ('name::', 'Lateral fan-shaped neuron Fl', 'id:', 'nlx_147393')
# ('name::', 'DN1a neuron', 'id:', 'nlx_148120')
# ('name::', 'Extrinsic pb neuron', 'id:', 'nlx_147395')
# ('name::', 'Extrinsic neuron', 'id:', 'nlx_147394')
# ('name::', 'Extrinsic no neuron', 'id:', 'nlx_147396')
# ('name::', 'Intrinsic vbo neuron', 'id:', 'nlx_147399')
# ('name::', 'Intrinsic neuron (FBbt Term)', 'id:', 'nlx_147398')
# ('         syn::', 'local interneuron')
# ('name::', 'Kenyon cell', 'id:', 'nlx_147420')
# ('         syn::', 'intrinsic cell of mushroom body')
# ('name::', 'Tergal depressor of trochanter muscle motor neuron', 'id:', 'nlx_147783')
# ('name::', 'Fan-shaped neuron F3', 'id:', 'nlx_148217')
# ('         syn::', 'fan shaped neuron F3')
# ('name::', 'Hippocampus CA3 pyramidal cell', 'id:', 'sao383526650')
# ('         syn::', 'Hippocampal CA3 Pyramidal Neuron')
# ('         syn::', 'CA3 pyramidal neuron')
# ('         syn::', 'CA3 pyramidal cell')
# ('name::', 'VesA neuron', 'id:', 'nlx_146759')
# ('name::', 'Eb-pb-vbo neuron', 'id:', 'nlx_147371')
# ('name::', 'Fan-shaped neuron F4', 'id:', 'nlx_148218')
# ('         syn::', 'fan shaped neuron F4')
# ('name::', 'Hirudo Retzius cell', 'id:', 'nlx_31744')
# ('         syn::', 'Retzius')
# ('         syn::', 'R Cell')
# ('name::', 'Optic lobe neuron', 'id:', 'nlx_147433')
# ('name::', 'Abducens nucleus motor neuron', 'id:', 'nlx_16848')
# ('         syn::', 'abducens nucleus motor cell')
# ('         syn::', '6th nerve motor neuron')
# ('         syn::', 'VIth nerve motor neuron')
# ('name::', 'Stomatogastric ganglion anterior burster neuron', 'id:', 'nlx_152047')
# ('name::', 'Rh5 photoreceptor of Bolwig organ', 'id:', 'nlx_148467')
# ('         syn::', "Rh5-expressing photoreceptor of Bolwig''s organ")
# ('name::', 'Chemosensory neuron of adult labial sensillum 9', 'id:', 'nlx_148464')
# ('name::', 'Chemosensory neuron of adult labial sensillum 7', 'id:', 'nlx_148465')
# ('name::', 'Chemosensory neuron of adult labial sensillum 8', 'id:', 'nlx_148462')
# ('name::', 'Mechanosensory neuron of adult labial sensillum 8', 'id:', 'nlx_148463')
# ('name::', 'Mechanosensory neuron of adult labial sensillum 6', 'id:', 'nlx_148460')
# ('name::', 'Mechanosensory neuron of adult labial sensillum 9', 'id:', 'nlx_148461')
# ('name::', 'Adult anterior LK leucokinin neuron', 'id:', 'nlx_149018')
# ('         syn::', 'adult ALK neuron')
# ('name::', 'Vertical fiber system neuron pb3', 'id:', 'nlx_148239')
# ('name::', 'Vertical fiber system neuron pb4', 'id:', 'nlx_148238')
# ('name::', 'Adult optic lobe OL tachykinin neuron', 'id:', 'nlx_149006')
# ('         syn::', 'adult OL neuron')
# ('name::', 'Adult tachykinin neuron of the thoracic-abdominal ganglion', 'id:', 'nlx_149010')
# ('name::', 'Vertical fiber system neuron pb5', 'id:', 'nlx_148237')
# ('name::', 'Adult leucokinin SELK neuron of the subesophageal ganglion', 'id:', 'nlx_149015')
# ('         syn::', 'adult SELK neuron')
# ('name::', 'Vertical fiber system neuron pb7', 'id:', 'nlx_148235')
# ('name::', 'Adult lateral horn LHKL leucokinin neuron', 'id:', 'nlx_149017')
# ('         syn::', 'LHLK')
# ('name::', 'Adult protocerebral MPP tachykinin neuron', 'id:', 'nlx_149004')
# ('         syn::', 'adult MPP neuron')
# ('name::', 'Bed nucleus of the stria terminalis spiny neuron with chandelier-like axon', 'id:', 'BAMSC992')
# ('         syn::', 'dense axon plexus forming neuron')
# ('         syn::', 'dense axon plexus forming cell')
# ('         syn::', 'BNST spiny neuron with chandelier-like axon')
# ('name::', 'Adult protocerebral LPP1 tachykinin neuron', 'id:', 'nlx_149003')
# ('         syn::', 'adult LPP1 neuron')
# ('name::', 'Trapezoid body principal cell', 'id:', 'nifext_78')
# ('         syn::', 'Trapezoid body principal neuron')
# ('name::', 'Accessory nucleus motor neuron', 'id:', 'nlx_83979')
# ('         syn::', 'spinal accessory nerve')
# ('         syn::', 'acessory nucleus motor cell')
# ('         syn::', '11th nerve motor neuron')
# ('         syn::', 'XIth nerve motor neuron')
# ('name::', 'Adult protocerebral LPP2 tachykinin neuron', 'id:', 'nlx_149002')
# ('         syn::', 'adult LPP2 neuron')
# ('name::', 'Vertical fiber system neuron pb2', 'id:', 'nlx_148240')
# ('name::', 'Terminal organ neuron of dorsal organ ganglion', 'id:', 'nlx_148504')
# ('         syn::', 'TODO neuron')
# ('name::', 'Labral sense organ neuron', 'id:', 'nlx_147736')
# ('name::', 'Ventral cibarial sense organ neuron of proximal sensillum', 'id:', 'nlx_147735')
# ('name::', 'Cibarial pump muscle neuron', 'id:', 'nlx_147733')
# ('name::', 'Dorsal cibarial sense organ neuron', 'id:', 'nlx_147732')
# ('name::', 'Giant fiber neuron', 'id:', 'nlx_147730')
# ('         syn::', 'GF')
# ('name::', 'Adult labial sensory neuron', 'id:', 'nlx_147739')
# ('name::', 'Scolopidial neuron', 'id:', 'nlx_147853')
# ('name::', 'Retina stratified amacrine cell', 'id:', 'BAMSC1013')
# ('name::', 'Retina wide field diffuse amacrine cell', 'id:', 'BAMSC1012')
# ('name::', 'Retina C ganglion cell', 'id:', 'BAMSC1011')
# ('         syn::', 'Retina ganglion cell C')
# ('name::', 'Retina B ganglion cell', 'id:', 'BAMSC1010')
# ('         syn::', 'Retina ganglion cell B')
# ('name::', 'Retina type 3 cone bipolar cell', 'id:', 'BAMSC1017')
# ('         syn::', 'type 3 cone bipolar cell')
# ('name::', 'Retina type 2 cone bipolar cell', 'id:', 'BAMSC1016')
# ('         syn::', 'type 2 cone bipolar cell')
# ('name::', 'VesD neuron', 'id:', 'nlx_146762')
# ('name::', 'Retina type 5 cone bipolar cell', 'id:', 'BAMSC1019')
# ('         syn::', 'type 5 cone bipolar cell')
# ('name::', 'Retina type 4 cone bipolar cell', 'id:', 'BAMSC1018')
# ('         syn::', 'type 4 cone bipolar cell')
# ('name::', 'Dentate gyrus spiny CR cell', 'id:', 'nlx_78883')
# ('         syn::', 'DG Spiny CR immunoreactive cell')
# ('         syn::', 'DG Spiny CR-positive interneurons')
# ('name::', 'Zoidberg Neuron', 'id:', 'nlx_155547')
# ('         syn::', 'Starburst Neuron')
# ('         syn::', 'Starburst Amacrine Cell')
# ('         syn::', 'n00b neuron')
# ('         syn::', 'Zoidberg cell')
# ('name::', 'Pacemaker neuron', 'id:', 'nlx_147931')
# ('name::', 'Spinal cord ventral horn interneuron V2b', 'id:', 'nlx_144180')
# ('name::', 'Zone C Johnston organ neuron', 'id:', 'nlx_148429')
# ('         syn::', 'zone C JON')
# ('name::', 'Olfactory bulb (accessory) granule cell', 'id:', 'nlx_cell_20090401')
# ('         syn::', 'Accessory olfactory bulb granule neuron')
# ('         syn::', 'Accessory olfactory bulb granule cell')
# ('name::', 'Ganglion cell', 'id:', 'nlx_147840')
# ('name::', 'Serotonergic-abdominal giant neuron', 'id:', 'nlx_148988')
# ('         syn::', 's-Abg')
# ('name::', 'Multidendritic neuron', 'id:', 'nlx_147849')
# ('         syn::', 'Type II neuron')
# ('name::', 'Eo neuron', 'id:', 'nlx_147848')
# ('name::', 'Type III sensory neuron of ventral ipsilateral fibers', 'id:', 'nlx_147742')
# ('name::', 'Type IV sensory neuron of dorsal ipsilateral fibers', 'id:', 'nlx_147743')
# ('name::', 'Type I sensory neuron of coiled fibers', 'id:', 'nlx_147740')
# ('name::', 'Type II sensory neuron of shrubby fibers', 'id:', 'nlx_147741')
# ('name::', 'Type VII sensory neuron of central fibers', 'id:', 'nlx_147746')
# ('name::', 'Adult labial interneuron', 'id:', 'nlx_147747')
# ('name::', 'Type V sensory neuron of ventral contralateral fibers', 'id:', 'nlx_147744')
# ('name::', 'Type VI sensory neuron of dorsal contralateral fibers', 'id:', 'nlx_147745')
# ('name::', 'Type A interneuron', 'id:', 'nlx_147748')
# ('name::', 'Mushroom body intrinsic neuron', 'id:', 'nlx_148164')
# ('name::', "V'es3 neuron", 'id:', 'nlx_146769')
# ('name::', "V'es2 neuron", 'id:', 'nlx_146768')
# ('name::', 'Mushroom body medial lobe arborizing neuron 2', 'id:', 'nlx_148578')
# ('         syn::', 'MB-M2')
# ('name::', 'Retina amacrine cell', 'id:', 'nifext_36')
# ('         syn::', 'Amacrine Neuron type II')
# ('         syn::', 'Type II Amacrine cell')
# ('name::', 'Retina parasol bipolar cell', 'id:', 'nifext_35')
# ('         syn::', 'Parasol cell')
# ('         syn::', 'Retina bipolar cell parasol')
# ('name::', 'Retina midget bipolar cell', 'id:', 'nifext_34')
# ('         syn::', 'Midget cell')
# ('         syn::', 'Retina bipolar cell midget')
# ('name::', 'Retina bipolar cell off', 'id:', 'nifext_33')
# ('         syn::', 'Off cell')
# ('name::', 'Retina bipolar cell on', 'id:', 'nifext_32')
# ('         syn::', 'On cell')
# ('name::', 'Retina bipolar cell', 'id:', 'nifext_31')
# ('         syn::', 'Retinal Bipolar Neuron')
# ('         syn::', 'retinal bipolar cell')
# ('name::', 'Retina displaced amacrine cell', 'id:', 'nifext_39')
# ('         syn::', 'Displaced amacrine cell')
# ('         syn::', 'Retina amacrine cell displaced')
# ('name::', 'Retina interplexiform cell', 'id:', 'nifext_38')
# ('         syn::', 'Interplexiform amacrine cell')
# ('name::', 'Mushroom body medial lobe arborizing neuron 3', 'id:', 'nlx_148579')
# ('         syn::', 'MB-M3')
# ('name::', 'LesD neuron', 'id:', 'nlx_146735')
# ('name::', 'Spinal cord ventral horn interneuron IB', 'id:', 'nifext_111')
# ('         syn::', 'IB Interneuron')
# ('name::', 'Spinal cord ventral horn interneuron IA', 'id:', 'nifext_110')
# ('         syn::', 'Spinal Ia interneuron')
# ('         syn::', 'Spinal interneuron IA')
# ('name::', 'Spinal cord ventral horn interneuron Renshaw', 'id:', 'nifext_113')
# ('         syn::', 'Renshaw cell')
# ('         syn::', 'Renshaw interneuron')
# ('name::', 'Spinal cord ventral horn interneuron II', 'id:', 'nifext_112')
# ('name::', 'Olfactory tubercle Islets of Calleja DA cell', 'id:', 'nifext_155')
# ('         syn::', 'Islands of Calleja dopamine cell')
# ('         syn::', 'Islets of Calleja dopamine cell')
# ('         syn::', 'Olfactory tubercle Islets of Calleja DA neuron')
# ('name::', 'Spinal cord ventral horn interneuron FRA', 'id:', 'nifext_114')
# ('         syn::', 'FFA interneuron')
# ('         syn::', 'Flexor reflex afferent interneuron')
# ('name::', 'Olfactory epithelium main sensory cell', 'id:', 'nifext_116')
# ('         syn::', 'olfactory receptor cell')
# ('         syn::', 'olfactory sensory neuron')
# ('name::', 'Olfactory epithelium main supporting cell', 'id:', 'nifext_119')
# ('         syn::', 'sustentacular cell')
# ('         syn::', 'supporting cell')
# ('         syn::', 'sustentacular main olfactory epithelium supporting cell')
# ('name::', 'Olfactory cortex horizontal cell', 'id:', 'nifext_118')
# ('         syn::', 'Horizontal cell (olfactory)')
# ('         syn::', 'olfactory horizontal cell')
# ('name::', 'Stomatogastric ganglion pyloric dilator neuron', 'id:', 'nlx_152045')
# ('name::', 'LP1 neuron', 'id:', 'nlx_146580')
# ('name::', 'Neuroendocrine motor magnocellular neurosecretory cell', 'id:', 'nlx_cell_20090501')
# ('         syn::', 'Hypothalamic magnocellular neurosecretory cell')
# ('         syn::', 'Hypothalamic magnocellular neurosecretory neuron')
# ('         syn::', 'Magnocellular secretory neuron')
# ('name::', 'S-LNv neuron', 'id:', 'nlx_148119')
# ('         syn::', 's-LNv')
# ('name::', 'Neocortex bouquet double cell', 'id:', 'sao910084726')
# ('         syn::', 'Double Bouquet Cell')
# ('name::', 'Larval olfactory receptor neuron Or85c', 'id:', 'nlx_148744')
# ('         syn::', 'ORN (Or85c)')
# ('name::', 'Neocortex Martinotti cell', 'id:', 'nifext_55')
# ('         syn::', 'Martinotti cell')
# ('name::', 'Olfactory tubercle Islets of Calleja GABA cell', 'id:', 'nifext_154')
# ('         syn::', 'Islands of Calleja Gaba interneuron')
# ('         syn::', 'Islets of Calleja Gaba interneuron')
# ('         syn::', 'Olfactory tubercle Islets of Calleja GABA interneuron')
# ('name::', 'Median fan-shaped neuron Fm', 'id:', 'nlx_147392')
# ('         syn::', 'Fm1')
# ('name::', 'Abdominal intersegmental trachea-associated neuron istd', 'id:', 'nlx_146904')
# ('name::', 'Gustatory receptor neuron of the hypophysis', 'id:', 'nlx_148509')
# ('name::', 'Gustatory receptor neuron of the epiphysis', 'id:', 'nlx_148508')
# ('name::', 'Gustatory receptor neuron of terminal organ', 'id:', 'nlx_148505')
# ('name::', 'Dorsal motor nucleus of vagus motor neuron', 'id:', 'nlx_38336')
# ('name::', 'Gustatory receptor neuron of the ventral organ', 'id:', 'nlx_148507')
# ('name::', 'Gustatory receptor neuron of the dorsal organ', 'id:', 'nlx_148506')
# ('name::', 'Vertical fiber system neuron', 'id:', 'nlx_147368')
# ('         syn::', 'VFS')
# ('name::', 'Horizontal fiber system neuron', 'id:', 'nlx_147369')
# ('         syn::', 'HFS')
# ('name::', 'VesC neuron', 'id:', 'nlx_146761')
# ('name::', 'VesB neuron', 'id:', 'nlx_146760')
# ('name::', "V'esB neuron", 'id:', 'nlx_146767')
# ('name::', "V'esA neuron", 'id:', 'nlx_146766')
# ('name::', 'Ves3 neuron', 'id:', 'nlx_146765')
# ('name::', 'VesM neuron', 'id:', 'nlx_146764')
# ('name::', 'Adult DN period neuron', 'id:', 'nlx_147362')
# ('name::', 'DN1 neuron', 'id:', 'nlx_147363')
# ('name::', 'DN2 neuron', 'id:', 'nlx_147364')
# ('name::', 'DN3 neuron', 'id:', 'nlx_147365')
# ('name::', 'Small field neuron', 'id:', 'nlx_147367')
# ('name::', 'Antennal olfactory receptor neuron', 'id:', 'nlx_148073')
# ('         syn::', 'antennal ORN')
# ('name::', 'LP2 neuron', 'id:', 'nlx_148072')
# ('name::', 'Cochlear nucleus (ventral) multipolar cell', 'id:', 'nlx_cell_20081202')
# ('name::', 'Thalamus geniculate nucleus (lateral) principal neuron', 'id:', 'nlx_cell_20081203')
# ('         syn::', 'Relay cell')
# ('         syn::', 'Thalamic relay neuron')
# ('         syn::', 'Thalamus relay neuron')
# ('         syn::', 'Thalamocortical cell')
# ('         syn::', 'Thalamocortical neuron')
# ('         syn::', 'Thalamus relay cell')
# ('name::', 'Cochlear nucleus (ventral) spherical bushy cell', 'id:', 'nlx_cell_20081201')
# ('         syn::', 'Bushy neuron')
# ('         syn::', 'Bushy cell')
# ('         syn::', 'ventral cochlear nucleus bushy cell')
# ('name::', 'Neocortex Cajal-Retzius cell', 'id:', 'nlx_cell_20081206')
# ('         syn::', 'Cajal-Retzius Cell')
# ('name::', 'Abdominal posterior fascicle neuron', 'id:', 'nlx_147164')
# ('name::', 'Taste bud type 3 cell', 'id:', 'nlx_151577')
# ('name::', 'Spinal cord border cell', 'id:', 'nlx_143585')
# ('         syn::', 'Spinal border cell')
# ('         syn::', 'spinal border neuron')
# ('name::', 'Johnston organ neuron tonically activated by arista deflection', 'id:', 'nlx_148431')
# ('         syn::', "Johnston''s organ neuron tonically activated by arista deflection")
# ('name::', 'Johnston organ neuron phasically activated by arista deflection', 'id:', 'nlx_148430')
# ('         syn::', "Johnston''s organ neuron phasically activated by arista deflection")
# ('name::', 'Johnston organ neuron activated by tonic anterior arista deflection', 'id:', 'nlx_148433')
# ('         syn::', "Johnston''s organ neuron activated by tonic anterior arista deflection")
# ('name::', 'Johnston organ neuron activated by tonic posterior arista deflection', 'id:', 'nlx_148432')
# ('         syn::', "Johnston''s organ neuron activated by tonic posterior arista deflection")
# ('name::', 'Neocortex Dorsolateral Prefrontal Area layer 1 parvalbumin cell', 'id:', 'nlx_157255')
# ('         syn::', 'Neocortical interneurons')
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Retina Off-Upsilon Ganglion Cell', 'id:', 'nlx_144269')
# ('         syn::', 'Retina Ganglion Cell Off-Upsilon')
# ('name::', 'Superior colliculus stellate cell of the zone of vertical cells', 'id:', 'BAMSC1131')
# ('         syn::', 'stellate cell of the zone of vertical cells')
# ('name::', 'Lateral fan-shaped neuron Fl3', 'id:', 'nlx_148206')
# ('name::', 'Lateral fan-shaped neuron Fl4', 'id:', 'nlx_148207')
# ('name::', 'Lateral fan-shaped neuron Fl1', 'id:', 'nlx_148204')
# ('name::', 'Lateral fan-shaped neuron Fl2', 'id:', 'nlx_148205')
# ('name::', 'Lateral fan-shaped neuron FE1', 'id:', 'nlx_148208')
# ('name::', 'Lateral fan-shaped neuron ExFl1', 'id:', 'nlx_148209')
# ('name::', 'Trapezoid body medial nucleus principal cell', 'id:', 'nifext_79')
# ('         syn::', 'Principal Cells Medial Nucleus Trapezoid Body')
# ('         syn::', 'Trapezoid body medial nucleus principal neuron')
# ('name::', 'Stomatogastric ganglion lateral gastric neuron', 'id:', 'nlx_152044')
# ('name::', 'Somatogastric ganglion neuron', 'id:', 'nlx_151986')
# ('name::', 'Locus coeruleus NA neuron', 'id:', 'nlx_cell_20090202')
# ...
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Neocortex Dorsolateral Prefrontal Area layer 6 parvalbumin cell', 'id:', 'nlx_157283')
# ('         syn::', 'Neocortical interneurons')
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Neocortex Dorsolateral Prefrontal Area layer 3 parvalbumin cell', 'id:', 'nlx_157280')
# ('         syn::', 'Neocortical interneurons')
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Cochlear nucleus (dorsal) stellate cell', 'id:', 'nlx_153843')
# ('name::', 'Pdf neuron', 'id:', 'nlx_147480')
# ('         syn::', 'pigment-dispersing hormone-immunoreactive neuron')
# ('name::', 'Spinal cord ventral horn interneuron V3', 'id:', 'nlx_cell_100208')
# ('         syn::', 'V3 interneuron')
# ('name::', 'Dentate gyrus IS-II cell', 'id:', 'nlx_cell_091204')
# ('         syn::', 'DG Interneruon-specific II cell')
# ('name::', 'Hypothalamus vasopressin neuroendocrine magnocellular neuron', 'id:', 'nlx_268')
# ('name::', 'Segmental nerve pioneer neuron', 'id:', 'nlx_146443')
# ('         syn::', 'SN-pioneer')
# ('name::', 'Cholinergic neuron (FBbt Term)', 'id:', 'nlx_148005')
# ('name::', 'Olfactory receptor neuron of dorsal organ', 'id:', 'nlx_148006')
# ('         syn::', 'DO ORN')
# ('name::', 'Dentate gyrus trilaminar interneuron', 'id:', 'nlx_cell_100204')
# ('name::', 'Olfactory bulb (main) Blanes cell', 'id:', 'nifext_124')
# ('         syn::', 'Blanes Cell')
# ('         syn::', 'Olfactory bulb (main) deep short axon cell')
# ('         syn::', 'short axon cell')
# ('name::', 'Trapezoid body intrinsic cell', 'id:', 'nifext_80')
# ('         syn::', 'Trapezoid body intrinsic neuron')
# ('name::', 'Spinal cord ventral horn interneuron V0', 'id:', 'nlx_cell_100205')
# ('         syn::', 'V0 interneuron')
# ('name::', 'Neocortex Dorsolateral prefrontal area layer 3 Calbindin cell', 'id:', 'nlx_156749')
# ('         syn::', 'Neocortical interneurons')
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Sound activated Johnston organ neuron', 'id:', 'nlx_148421')
# ('         syn::', "sound activated Johnston''s organ neuron")
# ('name::', 'Antennal lobe (Manduca) principal neuron', 'id:', 'nlx_151688')
# ('         syn::', 'uniglomerular projection neuron')
# ('         syn::', 'medial-antenno-protocerebral-tract projection neuron')
# ('         syn::', 'inner-antennocerebral-tract projection neuron')
# ('name::', 'Antennal lobe (Manduca) interneuron', 'id:', 'nlx_151689')
# ('         syn::', 'multiglomerular local interneuron')
# ('name::', 'Olfactory bulb (main) mitral cell', 'id:', 'nifext_120')
# ('         syn::', 'Mitral neuron')
# ('name::', 'Mushroom body (Honey bee) Kenyon cell', 'id:', 'nlx_151687')
# ('         syn::', 'mushroom body intrinsic neuron')
# ('name::', 'Mesothoracic posterior fascicle neuron', 'id:', 'nlx_146841')
# ('name::', 'Zone E Johnston organ neuron', 'id:', 'nlx_148440')
# ('         syn::', 'zone E JON')
# ('name::', 'Dopaminergic PPL2c neuron', 'id:', 'nlx_148569')
# ('         syn::', 'PPL2c')
# ('name::', 'Dopaminergic PPL2ab neuron', 'id:', 'nlx_148568')
# ('         syn::', 'PPL2ab')
# ('name::', 'Dopaminergic PAL neuron', 'id:', 'nlx_148563')
# ('         syn::', 'PAL')
# ('name::', 'Dopaminergic PAM neuron', 'id:', 'nlx_148562')
# ('         syn::', 'PAM')
# ('name::', 'Dopaminergic PPL1 neuron', 'id:', 'nlx_148567')
# ('         syn::', 'PPL1')
# ('name::', 'Dopaminergic PPM3 neuron', 'id:', 'nlx_148566')
# ('         syn::', 'PPM3')
# ('name::', 'Dopaminergic PPM2 neuron', 'id:', 'nlx_148565')
# ('         syn::', 'PPM2')
# ('name::', 'Dopaminergic PPM1 neuron', 'id:', 'nlx_148564')
# ('         syn::', 'PPM1')
# ('name::', 'SpB neuron', 'id:', 'nlx_146741')
# ('name::', 'Hippocampus CA1 stratum oriens neuron', 'id:', 'nlx_cell_090807')
# ('         syn::', 'vertical cells (Lacaille and williams')
# ('         syn::', '1990)')
# ('name::', 'SpD neuron', 'id:', 'nlx_146743')
# ('name::', 'SpC neuron', 'id:', 'nlx_146742')
# ('name::', 'Zone B Johnston organ neuron', 'id:', 'nlx_148428')
# ('         syn::', 'zone B JON')
# ('name::', 'Olfactory cortex multipolar cell', 'id:', 'nlx_cell_091001')
# ('         syn::', 'Olfactory cortex large multipolar neuron')
# ('         syn::', 'Olfactory cortex large multipolar cell')
# ('name::', 'Olfactory cortex small globular cell', 'id:', 'nlx_cell_091002')
# ('name::', 'Olfactory cortex semilunar cell', 'id:', 'nlx_cell_091005')
# ('         syn::', 'semilunar cell')
# ('         syn::', 'semilunar neuron')
# ('name::', 'Hippocampus CA2 bistratified cell narrow', 'id:', 'nlx_cell_091004')
# ('         syn::', 'CA2 bistratified cell')
# ('name::', 'LLN', 'id:', 'nlx_148099')
# ('name::', 'VLN', 'id:', 'nlx_148098')
# ('name::', 'Projection neuron (FBbt Term)', 'id:', 'nlx_148097')
# ('name::', 'Local interneuron of adult antennal lobe', 'id:', 'nlx_148095')
# ('         syn::', 'LI')
# ('name::', 'Embryonic / larval olfactory receptor neuron', 'id:', 'nlx_148093')
# ('         syn::', 'larval ORN')
# ('name::', 'Ventral sensillum of wing vein 3 neuron', 'id:', 'nlx_148487')
# ('name::', 'Adult olfactory receptor neuron', 'id:', 'nlx_148091')
# ('         syn::', 'adult odorant receptor neuron')
# ('name::', 'Neurosecretory neuron', 'id:', 'nlx_147834')
# ('name::', 'DRG temperature cell', 'id:', 'nifext_90')
# ('         syn::', 'Temperature cell')
# ('name::', 'Intrinsic neuron', 'id:', 'nlx_cell_1003113')
# ('         syn::', 'local circuit neuron')
# ('         syn::', 'interneuron')
# ('name::', 'Olfactory tubercle Islets of Calleja large Type 2 hilar cell', 'id:', 'nlx_19563')
# ('name::', 'Serotonergic neuron (FBbt Term)', 'id:', 'nlx_147837')
# ('         syn::', 'serotonin neuron')
# ('name::', 'Neocortex stellate smooth cell', 'id:', 'sao770302354')
# ('         syn::', 'Cortical Smooth Stellate Cell')
# ('name::', 'Gracilis nucleus intrinsic cell', 'id:', 'nifext_95')
# ('name::', 'Gracilis nucleus principal cell', 'id:', 'nifext_94')
# ('name::', 'Mushroom body ventral lobe arborizing neuron 3', 'id:', 'nlx_148586')
# ('         syn::', 'MB-V3')
# ('name::', 'Pioneer neuron', 'id:', 'nlx_147832')
# ('name::', 'Mushroom body alpha / beta neuron', 'id:', 'nlx_148596')
# ('         syn::', 'alpha / beta Kenyon cell')
# ('name::', "Mushroom body alpha' / beta' neuron", 'id:', 'nlx_148597')
# ('         syn::', "mushroom body alpha'' / beta'' Kenyon cell")
# ('name::', 'Mushroom body pedunculus-medial lobe and vertical lobe arborizing neuron 2', 'id:', 'nlx_148594')
# ('         syn::', 'MB-MVP2')
# ('name::', 'Mushroom body gamma neuron', 'id:', 'nlx_148595')
# ('         syn::', 'gamma Kenyon cell')
# ('name::', 'Mushroom body pedunculus-vertical lobe arborizing neuron 1', 'id:', 'nlx_148592')
# ('         syn::', 'MB-VP1')
# ('name::', 'Mushroom body pedunculus-medial lobe and vertical lobe arborizing neuron 1', 'id:', 'nlx_148593')
# ('         syn::', 'MB-MVP1')
# ('name::', 'Mushroom body medial-vertical lobe arborizing neuron 2', 'id:', 'nlx_148590')
# ('         syn::', 'MB-MV2')
# ('name::', 'Mushroom body pedunculus-medial lobe arborizing neuron 1', 'id:', 'nlx_148591')
# ('         syn::', 'MB-MP1')
# ('name::', 'Adult dorsomedial neurosecretory cell', 'id:', 'nlx_149065')
# ('         syn::', 'MNC')
# ('name::', 'Dopaminergic dorso-lateral neuron', 'id:', 'nlx_148953')
# ('name::', 'Median fan-shaped neuron Fm2', 'id:', 'nlx_148187')
# ('name::', 'Gustatory receptor neuron', 'id:', 'nlx_147910')
# ('         syn::', 'GRN')
# ('name::', 'Dentate gyrus HICAP cell', 'id:', 'nlx_32288')
# ('         syn::', 'Hilar cell')
# ('         syn::', 'Hilar neuron')
# ('name::', 'Hippocampus CA1 lacunosum moleculare neuron', 'id:', 'nlx_92500')
# ('         syn::', 'CA1 LM neuron')
# ('name::', 'Bed nucleus of the stria terminalis beaded neuron', 'id:', 'BAMSC995')
# ('         syn::', 'BNST beaded cell')
# ('         syn::', 'BNST beaded neuron')
# ('name::', 'Bed nucleus of the stria terminalis superficial spiny neuron', 'id:', 'BAMSC990')
# ('         syn::', 'superficial spiny cell')
# ('         syn::', 'BNST superficial spiny neuron')
# ('name::', 'Bed nucleus of the stria terminalis common spiny neuron', 'id:', 'BAMSC991')
# ('         syn::', 'common spiny cell')
# ('         syn::', 'BNST common spiny neuron')
# ('name::', 'Aplysia buccal 4', 'id:', 'nlx_152070')
# ('         syn::', 'Aplysia buccal 5')
# ('name::', 'Bed nucleus of the stria terminalis dense axon plexus-forming neuron', 'id:', 'BAMSC993')
# ('         syn::', 'beaded cell')
# ('         syn::', 'BNST dense axon plexus-forming neuron')
# ('name::', 'Tritonia dorsal swim interneuron', 'id:', 'Tri0001043')
# ('         syn::', 'Cerebral Serotonergic Posterior Neuron')
# ('         syn::', 'Dorsal swim interneuron')
# ('         syn::', 'DSI')
# ('name::', 'Dentate gyrus axo-axonic cell', 'id:', 'nlx_54328')
# ('         syn::', 'DG Chandelier cell')
# ('name::', 'Pdf neuron close to calyx', 'id:', 'nlx_147484')
# ('name::', 'Spinal cord dorsal horn layer III-V interneuron', 'id:', 'nlx_151678')
# ('name::', 'Dentate gyrus MOPP cell', 'id:', 'nlx_47009')
# ('name::', 'Median fan-shaped neuron Fm1', 'id:', 'nlx_148186')
# ('name::', 'Small field neuron of the central complex', 'id:', 'nlx_148189')
# ('         syn::', 'columnar neuron of central complex')
# ('name::', 'Median fan-shaped neuron Fm3', 'id:', 'nlx_148188')
# ('name::', 'Spinal cord dorsal horn layer III-V projection neuron', 'id:', 'nlx_151677')
# ('name::', 'Spinal cord dorsal horn marginal neuron', 'id:', 'nlx_151676')
# ('name::', 'Prothoracic ventral neurosecretory neuron', 'id:', 'nlx_147768')
# ('name::', 'Larval olfactory receptor neuron Or83a', 'id:', 'nlx_148743')
# ('         syn::', 'ORN (Or83a)')
# ('name::', 'Larval olfactory receptor neuron Or82a', 'id:', 'nlx_148742')
# ('         syn::', 'ORN (Or82a)')
# ('name::', 'Larval olfactory receptor neuron Or74a', 'id:', 'nlx_148741')
# ('         syn::', 'ORN (Or74a)')
# ('name::', 'Larval olfactory receptor neuron Or67b', 'id:', 'nlx_148740')
# ('         syn::', 'ORN (Or67b)')
# ('name::', 'Larval olfactory receptor neuron Or94b', 'id:', 'nlx_148745')
# ('         syn::', 'ORN (Or94b)')
# ('name::', 'Hypothalamus oxytocin releasing neuroendocrine magnocellular neuron', 'id:', 'nlx_84773')
# ('name::', 'Medullary commissural inhibitory neuron', 'id:', 'nlx_152083')
# ('name::', 'Medullary collateral inhibitory neuron', 'id:', 'nlx_152082')
# ('name::', 'Neocortex chandelier cell', 'id:', 'nifext_57')
# ('         syn::', 'Cortical chandelier cell')
# ('         syn::', 'Chandelier cell')
# ('         syn::', 'Chandelier-type cell')
# ('name::', 'Neocortex basket cell', 'id:', 'nifext_56')
# ('         syn::', 'cortical basket cell')
# ('         syn::', 'basket cell')
# ('         syn::', 'cortical basket neuron')
# ('         syn::', 'Neocortical basket cell')
# ('         syn::', 'parvalbumin interneuron')
# ('name::', 'Neocortex polymorphic cell layer 5-6', 'id:', 'nifext_51')
# ('         syn::', 'polymorphic cell')
# ('         syn::', 'Layer 5-6 polymorphic cell')
# ('         syn::', 'Neocortex polymorphic neuron layer 5-6')
# ('name::', 'Neocortex pyramidal cell layer 5-6', 'id:', 'nifext_50')
# ('         syn::', 'deep pyramidal cell')
# ('         syn::', 'Neocortex pyramidal neuron layer 5-6')
# ('         syn::', 'Layer 5-6 pyramidal cell')
# ('         syn::', 'layer 5 pyramidal neuron')
# ('         syn::', 'layer 5 pyramidal cell')
# ('         syn::', 'Tufted layer 5 (TL5) pyramidal neurons')
# ('name::', 'Neocortex stellate layer 4 cell', 'id:', 'nifext_53')
# ('         syn::', 'Cortical stellate cell')
# ('         syn::', 'cortical stellate neuron')
# ('         syn::', 'cortical spiny stellate cell')
# ('name::', 'Cranial relay neuron', 'id:', 'nlx_152084')
# ('name::', 'Lch1 neuron', 'id:', 'nlx_148449')
# ('name::', 'Horizontal fiber system neuron pb2', 'id:', 'nlx_148248')
# ('name::', 'Aplysia buccal 51', 'id:', 'nlx_152108')
# ('name::', 'Hirudo P Cell', 'id:', 'nlx_79073')
# ('         syn::', 'Pressure Cell')
# ('         syn::', 'P Cell')
# ('name::', 'Cerebellum Lugaro cell', 'id:', 'nifext_133')
# ('name::', 'Cerebellum unipolar brush cell', 'id:', 'nifext_132')
# ('         syn::', 'Unipolar brush neuron')
# ('         syn::', 'Unipolar brush cell')
# ('name::', 'Dorsal root ganglion C non-nociceptive neuron', 'id:', 'nlx_152100')
# ('name::', 'Cerebellum stellate cell', 'id:', 'nifext_130')
# ('         syn::', 'Cerebellar stellate neuron')
# ('         syn::', 'Cerebellar stellate cell')
# ('name::', 'Ocellus retinula cell', 'id:', 'nlx_147816')
# ('name::', 'Aplysia buccal 20', 'id:', 'nlx_152107')
# ('name::', 'Cochlear nucleus (dorsal) unipolar brush cell', 'id:', 'nifext_135')
# ('         syn::', 'DCN glutamatergic cell')
# ('         syn::', 'Dorsal cochlear nucleus glutamatergic cell')
# ('name::', 'Neocortex candelabrum cell', 'id:', 'nifext_134')
# ('         syn::', 'candelabrum neuron')
# ('         syn::', 'candelabrum cell')
# ('name::', 'U1sib neuron', 'id:', 'nlx_146561')
# ('name::', 'Usib neuron', 'id:', 'nlx_146560')
# ('name::', 'U3sib neuron', 'id:', 'nlx_146563')
# ('name::', 'U2sib neuron', 'id:', 'nlx_146562')
# ('name::', 'Neocortex stellate cell', 'id:', 'nifext_52')
# ('         syn::', 'cortical stellate cell')
# ('         syn::', 'layer 4 stellate cell')
# ('         syn::', 'stellate cell cortical')
# ('name::', 'Pupal Pdf neuron close to calyx', 'id:', 'nlx_148525')
# ('name::', 'Pupal Pdf neuron', 'id:', 'nlx_148522')
# ('name::', 'Adult Pdf neuron', 'id:', 'nlx_148521')
# ('name::', 'Extra LNd neuron', 'id:', 'nlx_148520')
# ('name::', 'Aplysia buccal 30', 'id:', 'nlx_152511')
# ('name::', 'Pupal s-LNv neuron', 'id:', 'nlx_148529')
# ('name::', 'Large field neuron', 'id:', 'nlx_147382')
# ('name::', 'Ring neuron', 'id:', 'nlx_147383')
# ('name::', 'Class IV dendritic arborizing neuron', 'id:', 'nlx_148059')
# ('         syn::', 'class IV da')
# ('name::', 'Class III dendritic arborizing neuron', 'id:', 'nlx_148058')
# ('         syn::', 'class III da')
# ('name::', 'SpA neuron', 'id:', 'nlx_146740')
# ('name::', 'A2 neuron', 'id:', 'nlx_146709')
# ('name::', 'A1 neuron', 'id:', 'nlx_146708')
# ('name::', 'Type B interneuron', 'id:', 'nlx_147749')
# ('name::', 'Accumbens nucleus shell neuron', 'id:', 'nlx_151893')
# ('name::', 'Johnston organ neuron', 'id:', 'nlx_148419')
# ('         syn::', 'JON')
# ('name::', 'Accumbens nucleus core nucleus neuron', 'id:', 'nlx_151892')
# ('name::', 'Cerebellar deep nucleus principal neuron', 'id:', 'nlx_151895')
# ('name::', 'Suprachiasmatic nucleus principal neuron', 'id:', 'nlx_151894')
# ('         syn::', 'SCN neuron')
# ('name::', 'Head direction cell', 'id:', 'nlx_144208')
# ('         syn::', 'Head-direction cell')
# ('name::', 'Grid cell', 'id:', 'nlx_144209')
# ('name::', 'Adult dMP2 ILP7 neuron', 'id:', 'nlx_148840')
# ('name::', 'Neocortex stellate spiny cell', 'id:', 'sao1236796660')
# ('         syn::', 'Cortical Spiny Stellate Cell')
# ('name::', 'Bed nucleus of the stria terminalis triangular neuron', 'id:', 'BAMSC989')
# ('         syn::', 'triangular cell')
# ('         syn::', 'BNST triangular neuron')
# ('name::', 'Mesothoracic ventral neurosecretory neuron', 'id:', 'nlx_147774')
# ('name::', 'Neocortex Dorsolateral Prefrontal Area layer 2 parvalbumin cell', 'id:', 'nlx_157279')
# ('         syn::', 'Neocortical interneurons')
# ('         syn::', 'GABAergic interneurons')
# ('         syn::', 'Inhibitory interneurons')
# ('name::', 'Pupal tachykinin neuron of the central nervous system', 'id:', 'nlx_149021')
# ('name::', 'Adult tachykinin neuron of the central nervous system', 'id:', 'nlx_149020')
# ('name::', 'Adult leucokinin neuron of the central nervous system', 'id:', 'nlx_149023')
# ('name::', 'Aplysia buccal 31', 'id:', 'nlx_152516')
# ('         syn::', 'Aplysia buccal 31')
# ('         syn::', 'Aplysia buccal 32')
# ('name::', 'Hippocampus CA1 pyramidal cell', 'id:', 'sao830368389')
# ('         syn::', 'Hippocampal CA1 Pyramidal Neuron')
# ('         syn::', 'CA1 pyramidal neuron')
# ('         syn::', 'Hippocampal CA1 pyramidal cell')
# ('name::', 'Aplysia buccal 61', 'id:', 'nlx_152510')
# ('         syn::', 'Aplysia buccal 62')
# ('         syn::', 'B62')

# %%
import pickle
pickle.dump(hbp_cell_names_processed,  open('hbp_cell_names_processed.pckl',  'wb'))
pickle.dump(nlex_cell_names_processed, open('nlex_cell_names_processed.pckl', 'wb'))

# %%
print hbp_cell_names_processed['HBP_CELL:0000064']
# Out:
# [[u'HBP_MORPHOLOGY:0000019'],
#  [[u'HBP_MORPHOLOGY:0000019']],
#  [[u'HBP_MORPHOLOGY:0000019']],
#  [[u'HBP_MORPHOLOGY:0000019']]]

# %%
#print nlex_cell_names['nlx_cell_1006021']
#print nlex_cell_names_processed['nlx_cell_1006021']
# Out:
# ('Spinal cord ventral horn interneuron V0C', ['V0c interneuron', 'spinal cord V0c interneuron'])
# [[u'UNKN_REGION:4645', u'UNKN_REGION:240'], [[u'UNKN_REGION:4645', u'UNKN_REGION:240']], [[u'UNKN_REGION:4645', u'UNKN_REGION:240']]]

# %%
#%debug
hbp_hits={}
for hbp_id, hbp_cell_variants in hbp_cell_names_processed.items():
    hbp_variant = hbp_cell_variants[0] # just the 1st one TODO
    if len(hbp_variant) == 0:
        print('NO VARIANT FOR ', hbp_id, hbp_cell_names[hbp_id])
    else:
        hits = []
        for nlex_id, nlex_cell_variants in nlex_cell_names_processed.items():
            for variant in nlex_cell_variants:
                if len(variant) == 0: continue
                #print("sim: HBP::",hbp_variant, "NLEX::",variant, "nlex_id",nlex_id)
                sim = similarity2(hbp_variant, variant[0], use_inter_similarity=True)
                if sim[0] > 0:
                    hits.append((nlex_id,) + sim)
        hbp_hits[hbp_id] = hits
print('hits', len(hbp_hits))
#hit: (nlex_id, sim_score, explanations...)
# Out:
# ('NO VARIANT FOR ', 'HBP_CELL:0000065', ('Axonal Cell', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000010', ('neuron classified based on gene expression', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000003', ('neuron classified base morphological properties', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000001', ('neuron', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000000', ('cell', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000007', ('neuron classified based on neurotransmitter release', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000006', ('neuron classified based on connection properties', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000005', ('neuron classified based on molecular expression', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000004', ('neuron classified base electrical properties', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000009', ('neuron classified based on protein expression', []))
# ('NO VARIANT FOR ', 'HBP_CELL:0000033', ('neuron classified based on location', []))
# ('hits', 122)

# %%
#hbp_hits['HBP_CELL:0000028']

# %%
def get_key(item):
    return item[0]

for hbp_id, hits in hbp_hits.items():
    if len(hits) > 0:
        hits_sorted = sorted(hits, key=get_key)
        
        print('{} ({})'.format(hbp_cell_names[hbp_id][0], hbp_id))
        already_printed = []
        for nlex_id, score, explain in hits_sorted[:5]:
            if nlex_id not in already_printed:
                already_printed.append(nlex_id)
                print '* {} ({}, {})'.format(nlex_cell_names[nlex_id][0], round(score, 2), nlex_id)
        print ''
# Out:
# Nest Basket Cell (HBP_CELL:0000064)
# * Bed nucleus of the stria terminalis basket neuron (0.57, BAMSC988)
# * Neocortex basket cell (0.57, nifext_56)
#
# Cajal-Retzius cell like cell (HBP_CELL:0000061)
# * Neocortex Cajal-Retzius cell (0.57, nlx_cell_20081206)
#
# Chandelier Cell (HBP_CELL:0000060)
# * Bed nucleus of the stria terminalis spiny neuron with chandelier-like axon (0.44, BAMSC992)
# * Neocortex chandelier cell (0.57, nifext_57)
#
# Large Basket Cell (HBP_CELL:0000063)
# * Bed nucleus of the stria terminalis basket neuron (0.57, BAMSC988)
# * Neocortex basket cell (0.57, nifext_56)
#
# Small Basket Cell (HBP_CELL:0000062)
# * Bed nucleus of the stria terminalis basket neuron (0.57, BAMSC988)
# * Neocortex basket cell (0.57, nifext_56)
#
# Layer V Neurogliaform Cell (HBP_CELL:0000115)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer IV Neurogliaform Cell (HBP_CELL:0000114)
# * Neocortex stellate layer 4 cell (0.6, nifext_53)
# * Neocortex Dorsolateral prefrontal area layer 4 Calbindin cell (0.54, nlx_156750)
#
# Layer II/III Martinotti Cell (HBP_CELL:0000117)
# * Neocortex pyramidal layer 2-3 cell (0.58, nifext_49)
#
# Layer VI Neurogliaform Cell (HBP_CELL:0000116)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Horizontal Axon Cell (HBP_CELL:0000068)
# * Olfactory cortex horizontal cell (0.8, nifext_118)
# * Retina horizontal cell (0.8, nifext_40)
# * Horizontal fiber system neuron (1.0, nlx_147369)
# * Retina thick dendrite horizontal cell (0.8, nlx_152141)
#
# Layer II/III Neurogliaform Cell (HBP_CELL:0000113)
# * Neocortex pyramidal layer 2-3 cell (0.58, nifext_49)
#
# Layer VI Double Bouquet Cell (HBP_CELL:0000112)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer V Martinotti Cell (HBP_CELL:0000119)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer IV Martinotti Cell (HBP_CELL:0000118)
# * Neocortex stellate layer 4 cell (0.6, nifext_53)
# * Neocortex Martinotti cell (0.32, nifext_55)
# * Neocortex Dorsolateral prefrontal area layer 4 Calbindin cell (0.54, nlx_156750)
#
# Layer IV Bipolar Cell (HBP_CELL:0000098)
# * Retina type 2 cone bipolar cell (0.32, BAMSC1016)
# * Retina type 3 cone bipolar cell (0.32, BAMSC1017)
# * Retina type 4 cone bipolar cell (0.32, BAMSC1018)
# * Retina type 5 cone bipolar cell (0.32, BAMSC1019)
# * Retina type 6 cone bipolar cell (0.32, BAMSC1020)
#
# Layer V Bipolar Cell (HBP_CELL:0000099)
# * Retina type 2 cone bipolar cell (0.32, BAMSC1016)
# * Retina type 3 cone bipolar cell (0.32, BAMSC1017)
# * Retina type 4 cone bipolar cell (0.32, BAMSC1018)
# * Retina type 5 cone bipolar cell (0.32, BAMSC1019)
# * Retina type 6 cone bipolar cell (0.32, BAMSC1020)
#
# Layer I Neurogliaform Cell with Dense Axonal Arbour (HBP_CELL:0000091)
# * Neocortex Dorsolateral Prefrontal Area layer 1 parvalbumin cell (0.54, nlx_157255)
# * Hippocampus CA1 neurogliaform neuron (0.32, nlx_cell_1006031)
#
# Layer I Neurogliaform Cell with Sparse Axon Arbour (HBP_CELL:0000092)
# * Neocortex Dorsolateral Prefrontal Area layer 1 parvalbumin cell (0.54, nlx_157255)
# * Hippocampus CA1 neurogliaform neuron (0.32, nlx_cell_1006031)
#
# Layer I Descending Axon Cell (HBP_CELL:0000093)
# * Neocortex Dorsolateral Prefrontal Area layer 1 parvalbumin cell (0.6, nlx_157255)
#
# Layer I Horizontal Axon Cell (HBP_CELL:0000094)
# * Olfactory cortex horizontal cell (0.39, nifext_118)
# * Retina horizontal cell (0.39, nifext_40)
# * Horizontal fiber system neuron (0.43, nlx_147369)
# * Retina thick dendrite horizontal cell (0.39, nlx_152141)
#
# Layer I Large Axon Cell (HBP_CELL:0000095)
# * Neocortex Dorsolateral Prefrontal Area layer 1 parvalbumin cell (0.6, nlx_157255)
#
# Layer I Small Axon Cell (HBP_CELL:0000096)
# * Neocortex Dorsolateral Prefrontal Area layer 1 parvalbumin cell (0.6, nlx_157255)
#
# Layer II/III Bipolar Cell (HBP_CELL:0000097)
# * Retina type 2 cone bipolar cell (0.34, BAMSC1016)
# * Retina type 3 cone bipolar cell (0.34, BAMSC1017)
# * Retina type 4 cone bipolar cell (0.34, BAMSC1018)
# * Retina type 5 cone bipolar cell (0.34, BAMSC1019)
# * Retina type 6 cone bipolar cell (0.34, BAMSC1020)
#
# neuron expressing Calbindin (HBP_CELL:0000014)
# * Neocortex Dorsolateral prefrontal area layer 2 Calbindin cell (0.28, nlx_156739)
# * Neocortex Dorsolateral prefrontal area layer 3 Calbindin cell (0.28, nlx_156749)
#
# neuron expressing Somatostatin (HBP_CELL:0000015)
# * Neostriatum SOM/NOS cell (0.44, nifext_144)
#
# neuron expressing Parvalbumin (HBP_CELL:0000016)
# * Neostriatum gaba/parvalbumin interneuron (0.44, nifext_143)
# * Amygdala basolateral nuclear complex nonpyramidal PV chandelier cell (0.33, nlx_149091)
# * Neocortex Dorsolateral Prefrontal Area layer 1 parvalbumin cell (0.28, nlx_157255)
#
# pyramidal cell (HBP_CELL:0000018)
# * Colliculus superior pyramidal cell (0.8, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.8, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.57, BAMSC987)
#
# Layer II/III Double Bouquet Cell (HBP_CELL:0000109)
# * Neocortex pyramidal layer 2-3 cell (0.58, nifext_49)
#
# Layer VI Bipolar Cell (HBP_CELL:0000100)
# * Retina type 2 cone bipolar cell (0.32, BAMSC1016)
# * Retina type 3 cone bipolar cell (0.32, BAMSC1017)
# * Retina type 4 cone bipolar cell (0.32, BAMSC1018)
# * Retina type 5 cone bipolar cell (0.32, BAMSC1019)
# * Retina type 6 cone bipolar cell (0.32, BAMSC1020)
#
# Layer II/III Bitufted Cell (HBP_CELL:0000101)
# * Neocortex pyramidal layer 2-3 cell (0.58, nifext_49)
#
# Tufted Pyramidal Cell towards Layer I (HBP_CELL:0000036)
# * Colliculus superior pyramidal cell (0.32, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.32, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.28, BAMSC987)
#
# Thick Tufted Pyramidal Cell (HBP_CELL:0000037)
# * Colliculus superior pyramidal cell (0.57, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.57, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.44, BAMSC987)
#
# Tufted Pyramidal Cell towards Layer IV (HBP_CELL:0000035)
# * Colliculus superior pyramidal cell (0.32, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.32, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.28, BAMSC987)
#
# Narrow Pyramidal Cell projecting to thalamus (HBP_CELL:0000032)
# * Colliculus superior pyramidal cell (0.5, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.5, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.4, BAMSC987)
#
# Horizontal Pyramidal Cell (HBP_CELL:0000030)
# * Colliculus superior pyramidal cell (0.57, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.57, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.44, BAMSC987)
#
# Bipolar Pyramidal Cell (HBP_CELL:0000031)
# * Retina type 2 cone bipolar cell (0.44, BAMSC1016)
# * Retina type 3 cone bipolar cell (0.44, BAMSC1017)
# * Retina type 4 cone bipolar cell (0.44, BAMSC1018)
# * Retina type 5 cone bipolar cell (0.44, BAMSC1019)
# * Retina type 6 cone bipolar cell (0.44, BAMSC1020)
#
# Slender Tufted Pyramidal Cell (HBP_CELL:0000038)
# * Colliculus superior pyramidal cell (0.57, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.57, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.44, BAMSC987)
#
# Early bifurcating Thick Tufted Pyramidal Cell (HBP_CELL:0000039)
# * Colliculus superior pyramidal cell (0.44, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.44, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.36, BAMSC987)
#
# Layer VI Pyramidal Cell (HBP_CELL:0000029)
# * Colliculus superior pyramidal cell (0.39, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.39, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.32, BAMSC987)
#
# Layer II/III Pyramidal Cell (HBP_CELL:0000028)
# * Colliculus superior pyramidal cell (0.41, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.41, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.34, BAMSC987)
#
# tufted pyramidal cell (HBP_CELL:0000023)
# * Colliculus superior pyramidal cell (0.57, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.57, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.44, BAMSC987)
#
# GABAergic neuron (HBP_CELL:0000022)
# * Neostriatum gaba/parvalbumin interneuron (0.44, nifext_143)
# * Substantia nigra pars reticulata interneuron GABA (0.5, nifext_147)
#
# Spiny Stellate Cell (HBP_CELL:0000025)
# * Colliculus superior stellate neuron (0.57, BAMSC1129)
# * Superior colliculus stellate cell of the zone of vertical cells (0.44, BAMSC1131)
# * Superior colliculus stellate cell of the zone of optic fibers (0.5, BAMSC1132)
# * Bed nucleus of the stria terminalis spiny bipolar neuron (0.36, BAMSC986)
#
# Untufted Pyramidal Cell (HBP_CELL:0000024)
# * Colliculus superior pyramidal cell (0.57, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.57, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.44, BAMSC987)
#
# Star Pyramidal Cell (HBP_CELL:0000027)
# * Colliculus superior pyramidal cell (0.8, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.8, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.57, BAMSC987)
#
# Layer 4 Spiny Stellate Cell (HBP_CELL:0000026)
# * Colliculus superior stellate neuron (0.32, BAMSC1129)
# * Superior colliculus stellate cell of the zone of vertical cells (0.28, BAMSC1131)
# * Superior colliculus stellate cell of the zone of optic fibers (0.3, BAMSC1132)
# * Bed nucleus of the stria terminalis spiny bipolar neuron (0.24, BAMSC986)
#
# Layer VI Large Basket Cell (HBP_CELL:0000124)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer II/III Nest Basket Cell (HBP_CELL:0000125)
# * Bed nucleus of the stria terminalis basket neuron (0.34, BAMSC988)
# * Neocortex pyramidal layer 2-3 cell (0.58, nifext_49)
#
# Layer II/III Small Basket Cell (HBP_CELL:0000126)
# * Bed nucleus of the stria terminalis basket neuron (0.34, BAMSC988)
# * Neocortex pyramidal layer 2-3 cell (0.58, nifext_49)
#
# Layer IV Small Basket Cell (HBP_CELL:0000127)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex stellate layer 4 cell (0.6, nifext_53)
#
# Layer VI Martinotti Cell (HBP_CELL:0000120)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer II/III Large Basket Cell (HBP_CELL:0000121)
# * Bed nucleus of the stria terminalis basket neuron (0.34, BAMSC988)
# * Neocortex pyramidal layer 2-3 cell (0.58, nifext_49)
#
# Layer IV Large Basket Cell (HBP_CELL:0000122)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex stellate layer 4 cell (0.6, nifext_53)
#
# Layer V Large Basket Cell (HBP_CELL:0000123)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer V Small Basket Cell (HBP_CELL:0000128)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer VI Small Basket Cell (HBP_CELL:0000129)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Neurogliaform Cell with Dense Axonal Arbours (HBP_CELL:0000058)
# * Hippocampus CA1 neurogliaform neuron (0.57, nlx_cell_1006031)
#
# Martinotti Cell (HBP_CELL:0000055)
# * Neocortex Martinotti cell (0.57, nifext_55)
#
# Neurogliaform Cell (HBP_CELL:0000056)
# * Hippocampus CA1 neurogliaform neuron (0.57, nlx_cell_1006031)
#
# Neurogliaform Cell with Sparse Axonal Arbours (HBP_CELL:0000057)
# * Hippocampus CA1 neurogliaform neuron (0.57, nlx_cell_1006031)
#
# Layer V Slender Tufted Pyramidal Cell (HBP_CELL:0000050)
# * Colliculus superior pyramidal cell (0.32, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.32, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.28, BAMSC987)
#
# Layer VI Tufted Pyramidal Cell towards Layer I (HBP_CELL:0000051)
# * Colliculus superior pyramidal cell (0.31, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.31, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.27, BAMSC987)
#
# Basket Cell (HBP_CELL:0000052)
# * Bed nucleus of the stria terminalis basket neuron (0.57, BAMSC988)
# * Neocortex basket cell (0.57, nifext_56)
#
# Bipolar Cell (HBP_CELL:0000053)
# * Retina type 2 cone bipolar cell (0.57, BAMSC1016)
# * Retina type 3 cone bipolar cell (0.57, BAMSC1017)
# * Retina type 4 cone bipolar cell (0.57, BAMSC1018)
# * Retina type 5 cone bipolar cell (0.57, BAMSC1019)
# * Retina type 6 cone bipolar cell (0.57, BAMSC1020)
#
# GABAergic interneuron (HBP_CELL:0000133)
# * Neostriatum gaba/parvalbumin interneuron (0.44, nifext_143)
# * Substantia nigra pars reticulata interneuron GABA (0.5, nifext_147)
#
# Layer VI Nest Basket Cell (HBP_CELL:0000132)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer V Nest Basket Cell (HBP_CELL:0000131)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer IV Nest Basket Cell (HBP_CELL:0000130)
# * Bed nucleus of the stria terminalis basket neuron (0.32, BAMSC988)
# * Neocortex stellate layer 4 cell (0.6, nifext_53)
#
# Layer VI Chandelier Cell (HBP_CELL:0000108)
# * Bed nucleus of the stria terminalis spiny neuron with chandelier-like axon (0.28, BAMSC992)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer V Double Bouquet Cell (HBP_CELL:0000111)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer V Untufted Pyramidal Cell (HBP_CELL:0000049)
# * Colliculus superior pyramidal cell (0.32, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.32, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.28, BAMSC987)
#
# Layer V Early bifurcating Thick Tufted Pyramidal Cell (HBP_CELL:0000048)
# * Colliculus superior pyramidal cell (0.28, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.28, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.24, BAMSC987)
#
# Layer VI Bipolar Pyramidal Cell (HBP_CELL:0000047)
# * Retina type 2 cone bipolar cell (0.28, BAMSC1016)
# * Retina type 3 cone bipolar cell (0.28, BAMSC1017)
# * Retina type 4 cone bipolar cell (0.28, BAMSC1018)
# * Retina type 5 cone bipolar cell (0.28, BAMSC1019)
# * Retina type 6 cone bipolar cell (0.28, BAMSC1020)
#
# Layer VI Inverted Pyramidal Cell (HBP_CELL:0000046)
# * Colliculus superior pyramidal cell (0.39, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.39, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.32, BAMSC987)
#
# Layer VI Untufted Pyramidal Cell (HBP_CELL:0000045)
# * Colliculus superior pyramidal cell (0.32, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.32, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.28, BAMSC987)
#
# Layer V Late bifurcating Thick Tufted Pyramidal Cell (HBP_CELL:0000044)
# * Colliculus superior pyramidal cell (0.32, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.32, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.28, BAMSC987)
#
# Layer VI Tufted Pyramidal Cell towards Layer IV (HBP_CELL:0000043)
# * Colliculus superior pyramidal cell (0.31, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.31, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.27, BAMSC987)
#
# Inverted Pyramidal Cell (HBP_CELL:0000042)
# * Colliculus superior pyramidal cell (0.8, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.8, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.57, BAMSC987)
#
# Untufted Slender Pyramidal Cell (HBP_CELL:0000041)
# * Colliculus superior pyramidal cell (0.44, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.44, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.36, BAMSC987)
#
# Late bifurcating Thick Tufted Pyramidal Cell (HBP_CELL:0000040)
# * Colliculus superior pyramidal cell (0.57, BAMSC1123)
# * Colliculus superior inverted pyramidal cell (0.57, BAMSC1124)
# * Bed nucleus of the stria terminalis small pyramidal neuron (0.44, BAMSC987)
#
# Layer IV Bitufted Cell (HBP_CELL:0000102)
# * Neocortex stellate layer 4 cell (0.6, nifext_53)
# * Neocortex Dorsolateral prefrontal area layer 4 Calbindin cell (0.54, nlx_156750)
#
# Layer V Bitufted Cell (HBP_CELL:0000103)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer IV Chandelier Cell (HBP_CELL:0000106)
# * Bed nucleus of the stria terminalis spiny neuron with chandelier-like axon (0.28, BAMSC992)
# * Neocortex stellate layer 4 cell (0.6, nifext_53)
#
# Layer V Chandelier Cell (HBP_CELL:0000107)
# * Bed nucleus of the stria terminalis spiny neuron with chandelier-like axon (0.28, BAMSC992)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer VI Bitufted Cell (HBP_CELL:0000104)
# * Neocortex pyramidal cell layer 5-6 (0.47, nifext_50)
#
# Layer II/III Chandelier Cell (HBP_CELL:0000105)
# * Bed nucleus of the stria terminalis spiny neuron with chandelier-like axon (0.29, BAMSC992)
# * Neocortex pyramidal layer 2-3 cell (0.58, nifext_49)
#
# Layer IV Double Bouquet Cell (HBP_CELL:0000110)
# * Neocortex stellate layer 4 cell (0.6, nifext_53)
# * Neocortex Dorsolateral prefrontal area layer 4 Calbindin cell (0.54, nlx_156750)
